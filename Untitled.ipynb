# %%
import pandas as pd
import numpy as np
import geopandas

# %%
path = "2nd_capstone_project\co2_mm_mlo.csv"
co2 = pd.read_csv(path)

# %%
co2.head(5)
# Out:
#    year  month  decimal date  average  deseasonalized  ndays  sdev   unc
# 0  1958      3     1958.2027   315.70          314.43     -1 -9.99 -0.99
# 1  1958      4     1958.2877   317.45          315.16     -1 -9.99 -0.99
# 2  1958      5     1958.3699   317.51          314.71     -1 -9.99 -0.99
# 3  1958      6     1958.4548   317.24          315.14     -1 -9.99 -0.99
# 4  1958      7     1958.5370   315.86          315.18     -1 -9.99 -0.99

# %%
df = co2

# %%
df.shape
# Out:
# (780, 8)

# %%
df.tail(5)
# Out:
#      year  month  decimal date  average  deseasonalized  ndays  sdev   unc
# 775  2022     10     2022.7917   415.78          419.13     30  0.27  0.10
# 776  2022     11     2022.8750   417.51          419.51     25  0.52  0.20
# 777  2022     12     2022.9583   418.95          419.64     24  0.50  0.20
# 778  2023      1     2023.0417   419.47          419.14     31  0.40  0.14
# 779  2023      2     2023.1250   420.41          419.49     25  0.64  0.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            780 non-null    int64
#  1   month           780 non-null    int64
#  2   decimal date    780 non-null    float64
#  3   average         780 non-null    float64
#  4   deseasonalized  780 non-null    float64
#  5   ndays           780 non-null    int64
#  6   sdev            780 non-null    float64
#  7   unc             780 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 48.9 KB

# %%
community
# Out:
# ['Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Low Income and Minority',
#  'Minority',
# ...

# %%
type = nj['OVERBURDENED_COMMUNITY_CRITERI'].isnull()

# %%
type
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3470    False
# 3471    False
# 3472    False
# 3473    False
# 3474    False
# Name: OVERBURDENED_COMMUNITY_CRITERI, Length: 3475, dtype: bool

# %%
type.describe()
# Out:
# count      3475
# unique        1
# top       False
# freq       3475
# Name: OVERBURDENED_COMMUNITY_CRITERI, dtype: object

# %%
nj['OVERBURDENED_COMMUNITY_CRITERI'].unique()
# Out:
# array(['Low Income and Minority', 'Minority', 'Low Income',
#        'Low Income, Minority, and Limited English',
#        'Minority and Limited English', 'Limited English',
#        'Low Income and Limited English', 'Adjacent'], dtype=object)
