# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NJ_education_2018_2019 = 'C:/Users/butle/Downloads/Database_DistrictStateDetail/2018-19 SPR Database DistrictStateDetail_040620.xlsx'
df = pd.read_excel(NJ_education_2018_2019)

# %%
df.head()
# Out:
#    COUNTY_CODE COUNTY_NAME  DISTRICT_CODE  \
# 0            1    Atlantic             10
# 1            1    Atlantic            110
# 2            1    Atlantic            120
# 3            1    Atlantic            125
# 4            1    Atlantic            570
#
#                                       DISTRICT_NAME GRADESPAN  \
# 0                   Absecon Public Schools District     PK-08
# 1                     Atlantic City School District     PK-12
# 2        Atlantic County Vocational School District     09-12
# 3  Atlantic County Special Services School District     PK-12
# 4                 Brigantine Public School District     PK-08
#
#             SUPERINTENDENT                   ADDRESS          CITY_STATE_ZIP  \
# 0        Dr. Daniel Dooley         800 Irelan Avenue        Absecon NJ 08201
# 1       Mr. Barry Caldwell      1300 Atlantic Avenue  Atlantic City NJ 08401
# 2      Dr. Philip Guenther      5080 Atlantic Avenue   Mays Landing NJ 08330
# ...
