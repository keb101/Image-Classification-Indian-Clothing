# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ejscreen_2021 = '/Users/butler/Documents/hp/Capstone_Two/data/raw/EJSCREEN_2020_StatePctile.csv'
df = pd.read_csv(ejscreen_2021)

# %%
df.shape
# Out:
# (220333, 124)

# %%
df.head()
# Out:
#    OBJECTID           ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP     D_PM25_2  \
# 0         1  10010201001    Alabama        AL       4        636  -492.025529
# 1         2  10010201002    Alabama        AL       4       1287 -2053.083414
# 2         3  10010202001    Alabama        AL       4        810  1846.126938
# 3         4  10010202002    Alabama        AL       4       1218  1392.075305
# 4         5  10010203001    Alabama        AL       4       2641  -769.374640
#
#    B_PM25_D2  P_PM25_D2    D_OZONE_2  ...  \
# 0          6       52.0 -1866.386370  ...
# 1          4       30.0 -7787.902602  ...
# 2          8       75.0  7002.783717  ...
# 3          8       72.0  5280.461532  ...
# 4          5       48.0 -2911.892606  ...
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# ...

# %%
df.tail()
# Out:
#         OBJECTID            ID   STATE_NAME ST_ABBREV  REGION  ACSTOTPOP  \
# 220328    220329  721537506011  Puerto Rico        PR       2        699
# 220329    220330  721537506012  Puerto Rico        PR       2       2432
# 220330    220331  721537506013  Puerto Rico        PR       2        976
# 220331    220332  721537506021  Puerto Rico        PR       2       1707
# 220332    220333  721537506022  Puerto Rico        PR       2        804
#
#         D_PM25_2  B_PM25_D2  P_PM25_D2  D_OZONE_2  ...  \
# 220328       NaN          0        NaN        NaN  ...
# 220329       NaN          0        NaN        NaN  ...
# 220330       NaN          0        NaN        NaN  ...
# 220331       NaN          0        NaN        NaN  ...
# 220332       NaN          0        NaN        NaN  ...
#
#                                        T_PNPL  T_PNPL_D2  \
# 220328  0.071 facilities/km distance (39%ile)     61%ile
# 220329  0.064 facilities/km distance (35%ile)     63%ile
# ...

# %%
df.describe()
# Out:
#             OBJECTID            ID         REGION      ACSTOTPOP  \
# count  220333.000000  2.203330e+05  220333.000000  220333.000000
# mean   110167.000000  2.863577e+11       5.167642    1480.894696
# std     63604.802768  1.633201e+11       2.482247     988.146948
# min         1.000000  1.001020e+10       1.000000       0.000000
# 25%     55084.000000  1.312101e+11       3.000000     890.000000
# 50%    110167.000000  2.816395e+11       5.000000    1266.000000
# 75%    165250.000000  4.200343e+11       7.000000    1817.000000
# max    220333.000000  7.215375e+11      10.000000   55407.000000
#
#             D_PM25_2      B_PM25_D2      P_PM25_D2      D_OZONE_2  \
# count  216046.000000  220333.000000  216046.000000  216075.000000
# mean      141.804077       5.678836      52.125825     120.102489
# std      3444.401415       2.703466      25.484327   16722.439926
# min    -90644.530105       0.000000       0.000000 -371198.063720
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220333 entries, 0 to 220332
# Columns: 124 entries, OBJECTID to Shape_Area
# dtypes: float64(60), int64(33), object(31)
# memory usage: 208.4+ MB

# %%
df.dtypes
# Out:
# OBJECTID          int64
# ID                int64
# STATE_NAME       object
# ST_ABBREV        object
# REGION            int64
#                  ...
# T_PTSDF_D2       object
# T_PWDIS          object
# T_PWDIS_D2       object
# Shape_Length    float64
# Shape_Area      float64
# Length: 124, dtype: object

# %%
df['ACSTOTPOP'].dtypes
# Out:
# dtype('int64')

# %%
df['PRE1960PCT'].dtypes
# Out:
# dtype('float64')

# %%
pol = df.astype({"ID":'int64'})

# %%
pol.head()
# Out:
#    OBJECTID           ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP     D_PM25_2  \
# 0         1  10010201001    Alabama        AL       4        636  -492.025529
# 1         2  10010201002    Alabama        AL       4       1287 -2053.083414
# 2         3  10010202001    Alabama        AL       4        810  1846.126938
# 3         4  10010202002    Alabama        AL       4       1218  1392.075305
# 4         5  10010203001    Alabama        AL       4       2641  -769.374640
#
#    B_PM25_D2  P_PM25_D2    D_OZONE_2  ...  \
# 0          6       52.0 -1866.386370  ...
# 1          4       30.0 -7787.902602  ...
# 2          8       75.0  7002.783717  ...
# 3          8       72.0  5280.461532  ...
# 4          5       48.0 -2911.892606  ...
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# ...

# %%
pop = pol.ACSTOTPOP
loc = pol.ID
pop
# Out:
# 0          636
# 1         1287
# 2          810
# 3         1218
# 4         2641
#           ...
# 220328     699
# 220329    2432
# 220330     976
# 220331    1707
# 220332     804
# Name: ACSTOTPOP, Length: 220333, dtype: int64

# %%
df.columns.get_loc('PM25')
# Out:
# 39

# %%
df.columns.get_loc('PRE1960PCT')
# Out:
# 57

# %%
df.columns.get_loc('PWDIS')
# Out:
# 69

# %%
df = df.iloc[:, 39:70]

# %%
df.head()
# Out:
#        PM25  B_PM25  P_PM25      OZONE  B_OZONE  P_OZONE     DSLPM  B_DSLPM  \
# 0  9.690899       7    69.0  36.760212        3     24.0  0.278663        5
# 1  9.690899       7    69.0  36.760212        3     24.0  0.278663        5
# 2  9.711240       8    70.0  36.836966        3     25.0  0.304313        6
# 3  9.711240       8    70.0  36.836966        3     25.0  0.304313        6
# 4  9.745683       8    71.0  36.884999        3     27.0  0.364215        7
#
#    P_DSLPM     CANCER  ...      PNPL  B_PNPL  P_PNPL      PRMP  B_PRMP  \
# 0     47.0  49.377032  ...  0.070942       8    79.0  0.085201       3
# 1     47.0  49.377032  ...  0.064344       8    76.0  0.073796       2
# 2     54.0  50.320741  ...  0.069234       8    78.0  0.077868       3
# 3     54.0  50.320741  ...  0.075614       9    81.0  0.086918       3
# 4     65.0  50.772140  ...  0.073913       9    80.0  0.080274       3
#
#    P_PRMP     PTSDF  B_PTSDF  P_PTSDF  PWDIS
# ...

# %%
df.columns
# Out:
# Index(['PM25', 'B_PM25', 'P_PM25', 'OZONE', 'B_OZONE', 'P_OZONE', 'DSLPM',
#        'B_DSLPM', 'P_DSLPM', 'CANCER', 'B_CANCR', 'P_CANCR', 'RESP', 'B_RESP',
#        'P_RESP', 'PTRAF', 'B_PTRAF', 'P_PTRAF', 'PRE1960PCT', 'B_LDPNT',
#        'P_LDPNT', 'PNPL', 'B_PNPL', 'P_PNPL', 'PRMP', 'B_PRMP', 'P_PRMP',
#        'PTSDF', 'B_PTSDF', 'P_PTSDF', 'PWDIS'],
#       dtype='object')

# %%
df.drop(['B_PM25', 'P_PM25', 'B_OZONE', 'P_OZONE', 'B_DSLPM', 'P_DSLPM', 'B_CANCR', 'P_CANCR', 'B_RESP', 'P_RESP', 'B_PTRAF', 'P_PTRAF', 'B_LDPNT', 'P_LDPNT', 'B_PNPL', 'P_PNPL', 'B_PRMP', 'P_PRMP', 'B_PTSDF', 'P_PTSDF'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS
# 0  0.070942  0.085201  0.586754    NaN
# 1  0.064344  0.073796  0.450601    NaN
# 2  0.069234  0.077868  0.653377    NaN
# 3  0.075614  0.086918  1.009395    NaN
# 4  0.073913  0.080274  1.177764    NaN

# %%
pop
# Out:
# 0          636
# 1         1287
# 2          810
# 3         1218
# 4         2641
#           ...
# 220328     699
# 220329    2432
# 220330     976
# 220331    1707
# 220332     804
# Name: ACSTOTPOP, Length: 220333, dtype: int64

# %%
# Adding population back in

df['POP'] = pop
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS   POP
# 0  0.070942  0.085201  0.586754    NaN   636
# 1  0.064344  0.073796  0.450601    NaN  1287
# 2  0.069234  0.077868  0.653377    NaN   810
# 3  0.075614  0.086918  1.009395    NaN  1218
# 4  0.073913  0.080274  1.177764    NaN  2641

# %%
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS   POP
# 0  0.070942  0.085201  0.586754    NaN   636
# 1  0.064344  0.073796  0.450601    NaN  1287
# 2  0.069234  0.077868  0.653377    NaN   810
# 3  0.075614  0.086918  1.009395    NaN  1218
# 4  0.073913  0.080274  1.177764    NaN  2641

# %%
# Making sure that all locations have non-zero population

df[df['POP'] == 0].count()
# Out:
# PM25           761
# OZONE          761
# DSLPM          541
# CANCER         541
# RESP           541
# PTRAF          231
# PRE1960PCT    1119
# PNPL          1119
# PRMP          1119
# PTSDF         1119
# PWDIS          155
# POP           1119
# dtype: int64

# %%
# Dropping any row with zero population

df = df[df['POP'] != 0]

# %%
df.shape
# Out:
# (219214, 12)

# %% [markdown]
# To prepare this for concatenation with health data, need to make health LocationName and df ID the same. ID has one extra digit for the block group, while LocationName only includes census tracts. Combining the block groups into census tracts by averaging the features scaled by population.

# %%
df['LocationName'] = loc // 10

# %%
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS   POP  LocationName
# 0  0.070942  0.085201  0.586754    NaN   636    1001020100
# 1  0.064344  0.073796  0.450601    NaN  1287    1001020100
# 2  0.069234  0.077868  0.653377    NaN   810    1001020200
# 3  0.075614  0.086918  1.009395    NaN  1218    1001020200
# 4  0.073913  0.080274  1.177764    NaN  2641    1001020300

# %%
df['PWDIS'].isnull().value_counts()
# Out:
# False    148558
# True      70656
# Name: PWDIS, dtype: int64

# %%
df[df['PWDIS'] == 0]
# Out:
# Empty DataFrame
# Columns: [PM25, OZONE, DSLPM, CANCER, RESP, PTRAF, PRE1960PCT, PNPL, PRMP, PTSDF, PWDIS, POP, LocationName]
# Index: []

# %%
df['PWDIS'].fillna(0, inplace=True)

# %%
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS   POP  LocationName
# 0  0.070942  0.085201  0.586754    0.0   636    1001020100
# 1  0.064344  0.073796  0.450601    0.0  1287    1001020100
# 2  0.069234  0.077868  0.653377    0.0   810    1001020200
# 3  0.075614  0.086918  1.009395    0.0  1218    1001020200
# 4  0.073913  0.080274  1.177764    0.0  2641    1001020300

# %%
# Changing index to LocationName

df.set_index('LocationName', inplace=True)

# %%
df.head()
# Out:
#                   PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# LocationName
# 1001020100    9.690899  36.760212  0.278663  49.377032  0.788052   91.015900
# 1001020100    9.690899  36.760212  0.278663  49.377032  0.788052    2.618744
# 1001020200    9.711240  36.836966  0.304313  50.320741  0.808744    4.679322
# 1001020200    9.711240  36.836966  0.304313  50.320741  0.808744  218.647491
# 1001020300    9.745683  36.884999  0.364215  50.772140  0.816773   69.644262
#
#               PRE1960PCT      PNPL      PRMP     PTSDF  PWDIS   POP
# LocationName
# 1001020100      0.272109  0.070942  0.085201  0.586754    0.0   636
# 1001020100      0.115464  0.064344  0.073796  0.450601    0.0  1287
# 1001020200      0.143243  0.069234  0.077868  0.653377    0.0   810
# 1001020200      0.342324  0.075614  0.086918  1.009395    0.0  1218
# 1001020300      0.083889  0.073913  0.080274  1.177764    0.0  2641

# %%
# Multiplying each column (other than POP) by population

for column in df:
    if column != 'POP':
        df[column] *= df['POP']

df.head()
# Out:
#                       PM25         OZONE       DSLPM         CANCER  \
# LocationName
# 1001020100     6163.412052  23379.494682  177.229712   31403.792102
# 1001020100    12472.187595  47310.392541  358.639369   63548.239678
# 1001020200     7866.104622  29837.942471  246.493133   40759.800150
# 1001020200    11828.290654  44867.424604  370.652636   61290.662448
# 1001020300    25738.349563  97413.283274  961.891212  134089.220432
#
#                      RESP          PTRAF  PRE1960PCT        PNPL        PRMP  \
# LocationName
# 1001020100     501.200905   57886.112454  173.061224   45.118825   54.187638
# 1001020100    1014.222586    3370.323085  148.602062   82.810299   94.975883
# 1001020200     655.082666    3790.250422  116.027027   56.079206   63.072946
# 1001020200     985.050231  266312.643524  416.950207   92.097829  105.865801
# 1001020300    2157.098024  183930.495773  221.551954  195.205478  212.003996
#
#                     PTSDF  PWDIS   POP
# LocationName
# ...

# %%
# Grouping rows with same LocationName. Each numerical value is given the population-weighted mean

def mean_normed_by_pop(x):
    x = x.sum() / x['POP'].sum()
    return x

df = df.groupby('LocationName', group_keys=False).apply(mean_normed_by_pop)

# %%
df.head()
# Out:
#                   PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# LocationName
# 1001020100    9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200    9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300    9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400    9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500    9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#               PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  POP
# LocationName
# 1001020100      0.167272  0.066526  0.077568  0.495631  0.000000  1.0
# 1001020200      0.262809  0.073066  0.083303  0.867199  0.000000  1.0
# 1001020300      0.078924  0.075626  0.082494  1.528117  0.000000  1.0
# 1001020400      0.114548  0.084700  0.087962  2.299506  0.000000  1.0
# 1001020500      0.000000  0.094754  0.091258  1.635841  0.000005  1.0

# %%
# POP was also changed, so it needs to be dropped

df.drop('POP', axis=1, inplace=True)

# %%
# Re-indexing

df.reset_index(names='LocationName', inplace=True)

# %%
df.head()
# Out:
#    LocationName      PM25      OZONE     DSLPM     CANCER      RESP  \
# 0    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 1    1001020200  9.711240  36.836966  0.304313  50.320741  0.808744
# 2    1001020300  9.745683  36.884999  0.364215  50.772140  0.816773
# 3    1001020400  9.761186  36.949586  0.447920  51.595926  0.835904
# 4    1001020500  9.791458  37.041363  0.499163  51.729998  0.841417
#
#         PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 0   31.854621    0.167272  0.066526  0.077568  0.495631  0.000000
# 1  133.186831    0.262809  0.073066  0.083303  0.867199  0.000000
# 2  183.972683    0.078924  0.075626  0.082494  1.528117  0.000000
# 3  448.339640    0.114548  0.084700  0.087962  2.299506  0.000000
# 4  198.171325    0.000000  0.094754  0.091258  1.635841  0.000005

# %%
df.tail()
# Out:
#        LocationName  PM25  OZONE     DSLPM     CANCER      RESP       PTRAF  \
# 73294   72153750501   0.0    0.0  0.053854  17.372062  0.260988   62.944027
# 73295   72153750502   0.0    0.0  0.058167  17.482087  0.260866  730.916547
# 73296   72153750503   0.0    0.0  0.049858  17.283555  0.258829  160.747911
# 73297   72153750601   0.0    0.0  0.055070  17.199448  0.258637   94.865143
# 73298   72153750602   0.0    0.0  0.057248  16.929739  0.256232  202.266125
#
#        PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 73294    0.009816  0.056186  0.720871  0.783596  0.020576
# 73295    0.072855  0.058919  0.851300  0.747859  0.024960
# 73296    0.067748  0.056212  0.604643  0.506445  0.006058
# 73297    0.061086  0.065172  1.636494  0.397525  0.016798
# 73298    0.167015  0.057998  0.557440  0.299630  0.000496

# %%
df.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/EJSCREEN_2020_interim.csv')

# %%
health_2022 = '/Users/butler/Documents/hp/Capstone_Two/data/raw/PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2022_release.csv'
df2 = pd.read_csv(health_2022)

# %%
df2.head()
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2020        AL   Alabama    Autauga        1001    1001020200      BRFSS
# 1  2020        AL   Alabama    Autauga        1001    1001020400      BRFSS
# 2  2020        AL   Alabama    Autauga        1001    1001021000      BRFSS
# 3  2020        AL   Alabama    Baldwin        1003    1003010905      BRFSS
# 4  2020        AL   Alabama    Baldwin        1003    1003010906      BRFSS
#
#           Category                                            Measure  \
# 0  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 1  Health Outcomes               Obesity among adults aged >=18 years
# 2  Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Outcomes                Stroke among adults aged >=18 years
# 4  Health Outcomes            Depression among adults aged >=18 years
#
#   Data_Value_Unit  ... Data_Value_Footnote  Low_Confidence_Limit  \
# ...

# %%
df2.shape
# Out:
# (2161543, 23)

# %%
df2.tail()
# Out:
#          Year StateAbbr  StateDesc CountyName  CountyFIPS  LocationName  \
# 2161538  2020        WI  Wisconsin   Waukesha       55133   55133204002
# 2161539  2020        WI  Wisconsin       Rock       55105   55105002700
# 2161540  2020        WI  Wisconsin   Waukesha       55133   55133203200
# 2161541  2020        WI  Wisconsin   Waukesha       55133   55133203101
# 2161542  2020        WI  Wisconsin   Waukesha       55133   55133200400
#
#         DataSource         Category  \
# 2161538      BRFSS       Prevention
# 2161539      BRFSS    Health Status
# 2161540      BRFSS  Health Outcomes
# 2161541      BRFSS       Prevention
# 2161542      BRFSS  Health Outcomes
#
#                                                    Measure Data_Value_Unit  \
# 2161538  Fecal occult blood test, sigmoidoscopy, or col...               %
# 2161539  Physical health not good for >=14 days among a...               %
# 2161540  Cancer (excluding skin cancer) among adults ag...               %
# ...

# %%
df2['Year'].unique()
# Out:
# array([2020, 2019])

# %%
df2 = df2[df2['Category'] == 'Health Outcomes']

# %%
df2.shape
# Out:
# (936284, 23)

# %%
df2[df2['LocationName'] == 1001020200]
# Out:
#        Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName  \
# 0      2020        AL   Alabama    Autauga        1001    1001020200
# 7505   2020        AL   Alabama    Autauga        1001    1001020200
# 7709   2019        AL   Alabama    Autauga        1001    1001020200
# 11227  2020        AL   Alabama    Autauga        1001    1001020200
# 13452  2020        AL   Alabama    Autauga        1001    1001020200
# 14063  2020        AL   Alabama    Autauga        1001    1001020200
# 14500  2019        AL   Alabama    Autauga        1001    1001020200
# 14995  2020        AL   Alabama    Autauga        1001    1001020200
# 16352  2020        AL   Alabama    Autauga        1001    1001020200
# 16616  2020        AL   Alabama    Autauga        1001    1001020200
# 17208  2020        AL   Alabama    Autauga        1001    1001020200
# 17291  2020        AL   Alabama    Autauga        1001    1001020200
# 18332  2020        AL   Alabama    Autauga        1001    1001020200
#
# ...

# %%
df[df['LocationName'] == 55133200400]
# Out:
#        LocationName      PM25     OZONE     DSLPM     CANCER      RESP  \
# 72123   55133200400  7.514909  43.06825  0.387525  22.748623  0.292665
#
#             PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 72123  180.213938    0.221044  0.222978  1.888956  1.393416  0.011332

# %%
df2.Category.nunique()
# Out:
# 1

# %%
df2.Category.unique()
# Out:
# array(['Health Outcomes'], dtype=object)

# %%
df2.shape
# Out:
# (936284, 23)

# %%
df2.DataSource.nunique()
# Out:
# 1

# %%
df2.DataSource.unique()
# Out:
# array(['BRFSS'], dtype=object)

# %%
df2.Data_Value_Footnote_Symbol.nunique()
# Out:
# 0

# %%
df2.Data_Value_Footnote.nunique()
# Out:
# 0

# %%
df2.DataValueTypeID.unique()
# Out:
# array(['CrdPrv'], dtype=object)

# %%
df2.DataValueTypeID.nunique()
# Out:
# 1

# %%
df2.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'CountyName', 'CountyFIPS',
#        'LocationName', 'DataSource', 'Category', 'Measure', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'TotalPopulation', 'Geolocation', 'LocationID', 'CategoryID',
#        'MeasureId', 'DataValueTypeID', 'Short_Question_Text'],
#       dtype='object')

# %%
df2.MeasureId.unique()
# Out:
# array(['COPD', 'OBESITY', 'STROKE', 'DEPRESSION', 'CASTHMA', 'TEETHLOST',
#        'ARTHRITIS', 'DIABETES', 'BPHIGH', 'CANCER', 'CHD', 'KIDNEY',
#        'HIGHCHOL'], dtype=object)

# %%
# Re-indexing

df2.set_index('LocationName', inplace=True)

# %%
df2.head()
# Out:
#               Year StateAbbr StateDesc CountyName  CountyFIPS DataSource  \
# LocationName
# 1001020200    2020        AL   Alabama    Autauga        1001      BRFSS
# 1001020400    2020        AL   Alabama    Autauga        1001      BRFSS
# 1001021000    2020        AL   Alabama    Autauga        1001      BRFSS
# 1003010905    2020        AL   Alabama    Baldwin        1003      BRFSS
# 1003010906    2020        AL   Alabama    Baldwin        1003      BRFSS
#
#                      Category  \
# LocationName
# 1001020200    Health Outcomes
# 1001020400    Health Outcomes
# 1001021000    Health Outcomes
# 1003010905    Health Outcomes
# 1003010906    Health Outcomes
#
#                                                         Measure  \
# LocationName
# 1001020200    Chronic obstructive pulmonary disease among ad...
# 1001020400                 Obesity among adults aged >=18 years
# 1001021000                 Obesity among adults aged >=18 years
# ...

# %%
# Getting rid of unneeded columns


df2 = df2.iloc[:, 9:]

# %%
df2.head()
# Out:
#                Data_Value_Type  Data_Value  Data_Value_Footnote_Symbol  \
# LocationName
# 1001020200    Crude prevalence         7.6                         NaN
# 1001020400    Crude prevalence        33.2                         NaN
# 1001021000    Crude prevalence        40.3                         NaN
# 1003010905    Crude prevalence         2.9                         NaN
# 1003010906    Crude prevalence        27.6                         NaN
#
#               Data_Value_Footnote  Low_Confidence_Limit  \
# LocationName
# 1001020200                    NaN                   6.8
# 1001020400                    NaN                  31.5
# 1001021000                    NaN                  39.3
# 1003010905                    NaN                   2.7
# 1003010906                    NaN                  26.3
#
#               High_Confidence_Limit  TotalPopulation  \
# LocationName
# 1001020200                      8.5             2170
# ...

# %%
MeasureId = df2['MeasureId']

# %%
df2 = df2.iloc[:, :2]

# %%
df2.head()
# Out:
#                Data_Value_Type  Data_Value
# LocationName
# 1001020200    Crude prevalence         7.6
# 1001020400    Crude prevalence        33.2
# 1001021000    Crude prevalence        40.3
# 1003010905    Crude prevalence         2.9
# 1003010906    Crude prevalence        27.6

# %%
# Adding back MeasureId

df2['MeasureId'] = MeasureId

# %%
# removing Data_Value_Type

df2.drop('Data_Value_Type', axis=1, inplace=True)

# %%
df2.shape
# Out:
# (936284, 2)

# %%
df2.head()
# Out:
#               Data_Value   MeasureId
# LocationName
# 1001020200           7.6        COPD
# 1001020400          33.2     OBESITY
# 1001021000          40.3     OBESITY
# 1003010905           2.9      STROKE
# 1003010906          27.6  DEPRESSION

# %%
# Re-indexing

df2.reset_index(names='LocationName', inplace=True)

# %%
df2.head()
# Out:
#    LocationName  Data_Value   MeasureId
# 0    1001020200         7.6        COPD
# 1    1001020400        33.2     OBESITY
# 2    1001021000        40.3     OBESITY
# 3    1003010905         2.9      STROKE
# 4    1003010906        27.6  DEPRESSION

# %%
df.head()
# Out:
#    LocationName      PM25      OZONE     DSLPM     CANCER      RESP  \
# 0    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 1    1001020200  9.711240  36.836966  0.304313  50.320741  0.808744
# 2    1001020300  9.745683  36.884999  0.364215  50.772140  0.816773
# 3    1001020400  9.761186  36.949586  0.447920  51.595926  0.835904
# 4    1001020500  9.791458  37.041363  0.499163  51.729998  0.841417
#
#         PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 0   31.854621    0.167272  0.066526  0.077568  0.495631  0.000000
# 1  133.186831    0.262809  0.073066  0.083303  0.867199  0.000000
# 2  183.972683    0.078924  0.075626  0.082494  1.528117  0.000000
# 3  448.339640    0.114548  0.084700  0.087962  2.299506  0.000000
# 4  198.171325    0.000000  0.094754  0.091258  1.635841  0.000005

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2['LocationName'].isin(df['LocationName']).value_counts()
# Out:
# True     936104
# False       180
# Name: LocationName, dtype: int64

# %%
# Combining dfs

df3 = df.merge(df2, how='inner', on='LocationName')
df3.head()
# Out:
#    LocationName      PM25      OZONE     DSLPM     CANCER      RESP  \
# 0    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 1    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 2    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 3    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 4    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
#
#        PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  PWDIS  Data_Value  \
# 0  31.854621    0.167272  0.066526  0.077568  0.495631    0.0         6.2
# 1  31.854621    0.167272  0.066526  0.077568  0.495631    0.0        37.0
# 2  31.854621    0.167272  0.066526  0.077568  0.495631    0.0        35.6
# 3  31.854621    0.167272  0.066526  0.077568  0.495631    0.0        14.6
# 4  31.854621    0.167272  0.066526  0.077568  0.495631    0.0        29.1
#
#    MeasureId
# 0     CANCER
# 1    OBESITY
# 2   HIGHCHOL
# 3  TEETHLOST
# 4  ARTHRITIS

# %%
df3.tail()
# Out:
#         LocationName      PM25      OZONE     DSLPM     CANCER      RESP  \
# 936099   56045951300  5.646642  47.797154  0.089088  15.420952  0.197472
# 936100   56045951300  5.646642  47.797154  0.089088  15.420952  0.197472
# 936101   56045951300  5.646642  47.797154  0.089088  15.420952  0.197472
# 936102   56045951300  5.646642  47.797154  0.089088  15.420952  0.197472
# 936103   56045951300  5.646642  47.797154  0.089088  15.420952  0.197472
#
#             PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# 936099  111.32253    0.420095  0.014525  0.923825  0.924472  0.000475
# 936100  111.32253    0.420095  0.014525  0.923825  0.924472  0.000475
# 936101  111.32253    0.420095  0.014525  0.923825  0.924472  0.000475
# 936102  111.32253    0.420095  0.014525  0.923825  0.924472  0.000475
# 936103  111.32253    0.420095  0.014525  0.923825  0.924472  0.000475
#
#         Data_Value   MeasureId
# 936099         7.4        COPD
# 936100        18.0  DEPRESSION
# ...

# %%
df3.shape
# Out:
# (936104, 14)

# %%
df3 = df3.rename({'LocationName':'CensusTract'}, axis=1)

# %%
df3.head()
# Out:
#    CensusTract      PM25      OZONE     DSLPM     CANCER      RESP      PTRAF  \
# 0   1001020100  9.690899  36.760212  0.278663  49.377032  0.788052  31.854621
# 1   1001020100  9.690899  36.760212  0.278663  49.377032  0.788052  31.854621
# 2   1001020100  9.690899  36.760212  0.278663  49.377032  0.788052  31.854621
# 3   1001020100  9.690899  36.760212  0.278663  49.377032  0.788052  31.854621
# 4   1001020100  9.690899  36.760212  0.278663  49.377032  0.788052  31.854621
#
#    PRE1960PCT      PNPL      PRMP     PTSDF  PWDIS  Data_Value  MeasureId
# 0    0.167272  0.066526  0.077568  0.495631    0.0         6.2     CANCER
# 1    0.167272  0.066526  0.077568  0.495631    0.0        37.0    OBESITY
# 2    0.167272  0.066526  0.077568  0.495631    0.0        35.6   HIGHCHOL
# 3    0.167272  0.066526  0.077568  0.495631    0.0        14.6  TEETHLOST
# 4    0.167272  0.066526  0.077568  0.495631    0.0        29.1  ARTHRITIS

# %% [markdown]
# Re-indexing as CensusTract will not be a feature.

# %%
df3.set_index('CensusTract', inplace=True)

# %%
cancer = df3[df3['MeasureId'] == 'CANCER']
cancer.shape
# Out:
# (72323, 13)

# %%
cancer = cancer.rename({'Data_Value': "Cancer_prevalence"}, axis=1)
cancer.drop('MeasureId', axis=1, inplace=True)

# %%
cancer.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005
#
#              Cancer_prevalence
# CensusTract
# 1001020100                 6.2
# ...

# %% [markdown]
# Making a separate dataframe for each health concern.

# %%
asthma = df3[df3['MeasureId'] == 'CASTHMA']
asthma = asthma.drop('MeasureId', axis = 1)
asthma = asthma.rename({'Data_Value': "Asthma_prevalence"}, axis=1)
asthma.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005
#
#              Asthma_prevalence
# CensusTract
# 1001020100                 9.8
# ...

# %%
asthma.shape
# Out:
# (72323, 12)

# %%
kidney = df3[df3['MeasureId'] == 'KIDNEY']  
kidney = kidney.drop('MeasureId', axis = 1)
kidney = kidney.rename({'Data_Value': "Kidney_prevalence"}, axis=1)
kidney.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005
#
#              Kidney_prevalence
# CensusTract
# 1001020100                 2.9
# ...

# %%
kidney.shape
# Out:
# (72323, 12)

# %%
chd = df3[df3['MeasureId'] == 'CHD']  
chd = chd.drop('MeasureId', axis = 1)
chd = chd.rename({'Data_Value': "CHD_prevalence"}, axis=1)
chd.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005
#
#              CHD_prevalence
# CensusTract
# 1001020100              6.6
# ...

# %%
stroke = df3[df3['MeasureId'] == 'STROKE']
stroke = stroke.drop('MeasureId', axis = 1)
stroke = stroke.rename({'Data_Value': "Stroke_prevalence"}, axis=1)
stroke.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  \
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005
#
#              Stroke_prevalence
# CensusTract
# 1001020100                 3.1
# ...

# %%
copd = df3[df3['MeasureId'] == 'COPD']
copd = copd.drop('MeasureId', axis = 1)
copd = copd.rename({'Crude_prevalence': "COPD_prevalence"}, axis=1)
copd.head()
# Out:
#                  PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  \
# CensusTract
# 1001020100   9.690899  36.760212  0.278663  49.377032  0.788052   31.854621
# 1001020200   9.711240  36.836966  0.304313  50.320741  0.808744  133.186831
# 1001020300   9.745683  36.884999  0.364215  50.772140  0.816773  183.972683
# 1001020400   9.761186  36.949586  0.447920  51.595926  0.835904  448.339640
# 1001020500   9.791458  37.041363  0.499163  51.729998  0.841417  198.171325
#
#              PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS  Data_Value
# CensusTract
# 1001020100     0.167272  0.066526  0.077568  0.495631  0.000000         8.1
# 1001020200     0.262809  0.073066  0.083303  0.867199  0.000000         7.6
# 1001020300     0.078924  0.075626  0.082494  1.528117  0.000000         8.3
# 1001020400     0.114548  0.084700  0.087962  2.299506  0.000000         7.2
# 1001020500     0.000000  0.094754  0.091258  1.635841  0.000005         5.9

# %% [markdown]
# **Environmental risk columns defined**
#
# PM25 = Particulate matter 2.5 level in air
#
# Ozone = Ozone level in air
#
# DSLPM = Diesel particulate matter level in air
#
# Cancer = Air toxics cancer risk
#
# RESP = Air toxics respiratory hazard index
#
# PTRAF = Traffic proximity and volume
#
# PRE1960PCT = % pre-1960 housing (lead paint indicator)
#
# PNPL = Proximity to National Priorities List (NPL) [superfund] sites
#
# PRMP = Proximity to Risk Management Plan (RMP) facilities, facilities that use extremely hazardous substances
#
# PTSDF = Proximity to Treatment Storage and Disposal facilities (TSDF)
#
# PWDIS = Indicator for major direct dischargers to water

# %% [markdown]
# Making a dataset for each health concern

# %%
copd.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/copd_data.csv')

# %%
asthma.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/asthma_data.csv')

# %%
stroke.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/stroke_data.csv')

# %%
cancer.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/cancer_data.csv')

# %%
chd.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/chd_data.csv')

# %%
kidney.to_csv('/Users/butler/Documents/hp/Capstone_Two/data/interim/kidney_data.csv')
