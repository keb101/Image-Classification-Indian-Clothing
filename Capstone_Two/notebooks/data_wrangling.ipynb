# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ejscreen_2021 = '/Users/butler/Documents/hp/Capstone_Two/data/raw/EJSCREEN_2020_StatePctile.csv'
df = pd.read_csv('/data/raw/EJSCREEN_2020_StatePctile.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 ejscreen_2021 = '/Users/butler/Documents/hp/Capstone_Two/data/raw/EJSCREEN_2020_StatePctile.csv'
# ----> 2 df = pd.read_csv('/data/raw/EJSCREEN_2020_StatePctile.csv')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/raw/EJSCREEN_2020_StatePctile.csv'

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#    OBJECTID           ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP     D_PM25_2  \
# 0         1  10010201001    Alabama        AL       4        636  -492.025529
# 1         2  10010201002    Alabama        AL       4       1287 -2053.083414
# 2         3  10010202001    Alabama        AL       4        810  1846.126938
# 3         4  10010202002    Alabama        AL       4       1218  1392.075305
# 4         5  10010203001    Alabama        AL       4       2641  -769.374640
#
#    B_PM25_D2  P_PM25_D2    D_OZONE_2  ...  \
# 0          6       52.0 -1866.386370  ...
# 1          4       30.0 -7787.902602  ...
# 2          8       75.0  7002.783717  ...
# 3          8       72.0  5280.461532  ...
# 4          5       48.0 -2911.892606  ...
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# 3  0.076 facilities/km distance (81%ile)     83%ile
# 4  0.074 facilities/km distance (80%ile)     32%ile
#
#                                   T_PRMP  T_PRMP_D2  \
# 0  0.085 facilities/km distance (23%ile)     53%ile
# 1  0.074 facilities/km distance (17%ile)     42%ile
# 2  0.078 facilities/km distance (20%ile)     67%ile
# 3  0.087 facilities/km distance (24%ile)     66%ile
# 4   0.08 facilities/km distance (21%ile)     51%ile
#
#                                 T_PTSDF  T_PTSDF_D2  T_PWDIS  T_PWDIS_D2  \
# 0  0.59 facilities/km distance (57%ile)      38%ile      NaN         NaN
# 1  0.45 facilities/km distance (52%ile)      23%ile      NaN         NaN
# 2  0.65 facilities/km distance (59%ile)      77%ile      NaN         NaN
# 3     1 facilities/km distance (69%ile)      78%ile      NaN         NaN
# 4   1.2 facilities/km distance (74%ile)      24%ile      NaN         NaN
#
#    Shape_Length    Shape_Area
# 0  13443.155206  6.040790e+06
# 1  11917.089598  7.834160e+06
# 2   7770.915121  2.900774e+06
# 3   6506.804784  1.793332e+06
# 4  11070.367848  5.461602e+06
#
# [5 rows x 124 columns]

# %%
df.tail()
# Out:
#         OBJECTID            ID   STATE_NAME ST_ABBREV  REGION  ACSTOTPOP  \
# 220328    220329  721537506011  Puerto Rico        PR       2        699
# 220329    220330  721537506012  Puerto Rico        PR       2       2432
# 220330    220331  721537506013  Puerto Rico        PR       2        976
# 220331    220332  721537506021  Puerto Rico        PR       2       1707
# 220332    220333  721537506022  Puerto Rico        PR       2        804
#
#         D_PM25_2  B_PM25_D2  P_PM25_D2  D_OZONE_2  ...  \
# 220328       NaN          0        NaN        NaN  ...
# 220329       NaN          0        NaN        NaN  ...
# 220330       NaN          0        NaN        NaN  ...
# 220331       NaN          0        NaN        NaN  ...
# 220332       NaN          0        NaN        NaN  ...
#
#                                        T_PNPL  T_PNPL_D2  \
# 220328  0.071 facilities/km distance (39%ile)     61%ile
# 220329  0.064 facilities/km distance (35%ile)     63%ile
# 220330  0.064 facilities/km distance (35%ile)     49%ile
# 220331  0.056 facilities/km distance (27%ile)     70%ile
# 220332  0.063 facilities/km distance (34%ile)     65%ile
#
#                                       T_PRMP  T_PRMP_D2  \
# 220328   1.1 facilities/km distance (74%ile)     81%ile
# 220329   1.5 facilities/km distance (83%ile)     88%ile
# 220330   2.3 facilities/km distance (91%ile)     79%ile
# 220331  0.53 facilities/km distance (44%ile)     80%ile
# 220332  0.62 facilities/km distance (51%ile)     76%ile
#
#                                      T_PTSDF  T_PTSDF_D2  \
# 220328  0.28 facilities/km distance (48%ile)      71%ile
# 220329  0.39 facilities/km distance (53%ile)      79%ile
# 220330   0.5 facilities/km distance (57%ile)      66%ile
# 220331  0.33 facilities/km distance (51%ile)      82%ile
# 220332  0.23 facilities/km distance (43%ile)      73%ile
#
#                                                   T_PWDIS  T_PWDIS_D2  \
# 220328  0.0025 toxicity-weighted concentration/meters ...      72%ile
# 220329  0.0032 toxicity-weighted concentration/meters ...      75%ile
# 220330  0.061 toxicity-weighted concentration/meters d...      86%ile
# 220331  0.000024 toxicity-weighted concentration/meter...      55%ile
# 220332  0.0015 toxicity-weighted concentration/meters ...      71%ile
#
#         Shape_Length    Shape_Area
# 220328  19751.958143  8.486394e+06
# 220329   6704.079316  1.744950e+06
# 220330   7737.485130  1.989274e+06
# 220331   5128.437876  1.265271e+06
# 220332  20006.384457  1.848868e+07
#
# [5 rows x 124 columns]

# %%
df.describe()
# Out:
#             OBJECTID            ID         REGION      ACSTOTPOP  \
# count  220333.000000  2.203330e+05  220333.000000  220333.000000
# mean   110167.000000  2.863577e+11       5.167642    1480.894696
# std     63604.802768  1.633201e+11       2.482247     988.146948
# min         1.000000  1.001020e+10       1.000000       0.000000
# 25%     55084.000000  1.312101e+11       3.000000     890.000000
# 50%    110167.000000  2.816395e+11       5.000000    1266.000000
# 75%    165250.000000  4.200343e+11       7.000000    1817.000000
# max    220333.000000  7.215375e+11      10.000000   55407.000000
#
#             D_PM25_2      B_PM25_D2      P_PM25_D2      D_OZONE_2  \
# count  216046.000000  220333.000000  216046.000000  216075.000000
# mean      141.804077       5.678836      52.125825     120.102489
# std      3444.401415       2.703466      25.484327   16722.439926
# min    -90644.530105       0.000000       0.000000 -371198.063720
# 25%     -1746.870154       4.000000      32.000000   -9156.587422
# 50%      -538.105932       6.000000      53.000000   -2793.854824
# 75%      1563.734759       8.000000      73.000000    7611.002317
# max     62799.333874      11.000000     100.000000  272045.350467
#
#           B_OZONE_D2     P_OZONE_D2  ...     B_LESHSPCT     P_LESHSPCT  \
# count  220333.000000  216046.000000  ...  220333.000000  220333.000000
# mean        5.677338      52.115503  ...       5.684006      50.877826
# std         2.700227      25.451861  ...       3.012208      29.231050
# min         0.000000       0.000000  ...       1.000000       0.000000
# 25%         4.000000      32.000000  ...       3.000000      25.000000
# 50%         6.000000      53.000000  ...       6.000000      52.000000
# 75%         8.000000      73.000000  ...       8.000000      76.000000
# max        11.000000     100.000000  ...      11.000000     100.000000
#
#            UNDER5PCT     B_UNDR5PCT     P_UNDR5PCT      OVER64PCT  \
# count  220333.000000  220333.000000  220333.000000  220333.000000
# mean        0.058312       5.293115      47.009272       0.164956
# std         0.040289       3.071742      29.795501       0.101952
# min         0.000000       1.000000       1.000000       0.000000
# 25%         0.030006       3.000000      20.000000       0.097784
# 50%         0.053263       5.000000      45.000000       0.150147
# 75%         0.080402       8.000000      73.000000       0.210931
# max         0.525000      11.000000     100.000000       1.000000
#
#           B_OVR64PCT     P_OVR64PCT  Shape_Length    Shape_Area
# count  220333.000000  220333.000000  2.203330e+05  2.203330e+05
# mean        5.908534      52.917339  2.159727e+04  1.035941e+08
# std         3.034565      29.508831  6.339526e+04  3.809275e+09
# min         1.000000       0.000000  3.015633e+02  5.494842e+03
# 25%         3.000000      28.000000  4.161934e+03  8.056123e+05
# 50%         6.000000      55.000000  7.461881e+03  2.223780e+06
# 75%         8.000000      79.000000  2.034583e+04  1.521968e+07
# max        11.000000     100.000000  8.214219e+06  1.289561e+12
#
# [8 rows x 93 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220333 entries, 0 to 220332
# Columns: 124 entries, OBJECTID to Shape_Area
# dtypes: float64(60), int64(33), object(31)
# memory usage: 208.4+ MB

# %%
df.dtypes
# Out:
# OBJECTID          int64
# ID                int64
# STATE_NAME       object
# ST_ABBREV        object
# REGION            int64
#                  ...
# T_PTSDF_D2       object
# T_PWDIS          object
# T_PWDIS_D2       object
# Shape_Length    float64
# Shape_Area      float64
# Length: 124, dtype: object

# %%
df['ACSTOTPOP'].dtypes
# Out:
# dtype('int64')

# %%
df['MINORPCT'].dtypes
# Out:
# dtype('float64')

# %%
df['PRE1960PCT'].dtypes
# Out:
# dtype('float64')

# %%
df['P_MINORPCT'].dtypes
# Out:
# dtype('float64')

# %%
pol = df.astype({"ID":'int64'})

# %%
pol.head()
# Out:
#    OBJECTID           ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP     D_PM25_2  \
# 0         1  10010201001    Alabama        AL       4        636  -492.025529
# 1         2  10010201002    Alabama        AL       4       1287 -2053.083414
# 2         3  10010202001    Alabama        AL       4        810  1846.126938
# 3         4  10010202002    Alabama        AL       4       1218  1392.075305
# 4         5  10010203001    Alabama        AL       4       2641  -769.374640
#
#    B_PM25_D2  P_PM25_D2    D_OZONE_2  ...  \
# 0          6       52.0 -1866.386370  ...
# 1          4       30.0 -7787.902602  ...
# 2          8       75.0  7002.783717  ...
# 3          8       72.0  5280.461532  ...
# 4          5       48.0 -2911.892606  ...
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# 3  0.076 facilities/km distance (81%ile)     83%ile
# 4  0.074 facilities/km distance (80%ile)     32%ile
#
#                                   T_PRMP  T_PRMP_D2  \
# 0  0.085 facilities/km distance (23%ile)     53%ile
# 1  0.074 facilities/km distance (17%ile)     42%ile
# 2  0.078 facilities/km distance (20%ile)     67%ile
# 3  0.087 facilities/km distance (24%ile)     66%ile
# 4   0.08 facilities/km distance (21%ile)     51%ile
#
#                                 T_PTSDF  T_PTSDF_D2  T_PWDIS  T_PWDIS_D2  \
# 0  0.59 facilities/km distance (57%ile)      38%ile      NaN         NaN
# 1  0.45 facilities/km distance (52%ile)      23%ile      NaN         NaN
# 2  0.65 facilities/km distance (59%ile)      77%ile      NaN         NaN
# 3     1 facilities/km distance (69%ile)      78%ile      NaN         NaN
# 4   1.2 facilities/km distance (74%ile)      24%ile      NaN         NaN
#
#    Shape_Length    Shape_Area
# 0  13443.155206  6.040790e+06
# 1  11917.089598  7.834160e+06
# 2   7770.915121  2.900774e+06
# 3   6506.804784  1.793332e+06
# 4  11070.367848  5.461602e+06
#
# [5 rows x 124 columns]

# %%
df.columns.get_loc('P_MINORPCT')
# Out:
# 77

# %% [markdown]
# To prepare this for concatenation with health data, need to make health LocationName and df ID the same. ID has one extra digit for the block group, while LocationName only includes census tracts. Combining the block groups into census tracts by averaging the features scaled by population.

# %%
pol['LocationName'] = pol['ID'] // 10
poll = pol.copy()
poll.head()
# Out:
# C:\Users\butle\AppData\Local\Temp\ipykernel_15896\3921973867.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pol['LocationName'] = pol['ID'] // 10
#    OBJECTID           ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP     D_PM25_2  \
# 0         1  10010201001    Alabama        AL       4        636  -492.025529
# 1         2  10010201002    Alabama        AL       4       1287 -2053.083414
# 2         3  10010202001    Alabama        AL       4        810  1846.126938
# 3         4  10010202002    Alabama        AL       4       1218  1392.075305
# 4         5  10010203001    Alabama        AL       4       2641  -769.374640
#
#    B_PM25_D2  P_PM25_D2    D_OZONE_2  ...  T_PNPL_D2  \
# 0          6       52.0 -1866.386370  ...     40%ile
# 1          4       30.0 -7787.902602  ...     19%ile
# 2          8       75.0  7002.783717  ...     85%ile
# 3          8       72.0  5280.461532  ...     83%ile
# 4          5       48.0 -2911.892606  ...     32%ile
#
#                                   T_PRMP  T_PRMP_D2  \
# 0  0.085 facilities/km distance (23%ile)     53%ile
# 1  0.074 facilities/km distance (17%ile)     42%ile
# 2  0.078 facilities/km distance (20%ile)     67%ile
# 3  0.087 facilities/km distance (24%ile)     66%ile
# 4   0.08 facilities/km distance (21%ile)     51%ile
#
#                                 T_PTSDF  T_PTSDF_D2  T_PWDIS  T_PWDIS_D2  \
# 0  0.59 facilities/km distance (57%ile)      38%ile      NaN         NaN
# 1  0.45 facilities/km distance (52%ile)      23%ile      NaN         NaN
# 2  0.65 facilities/km distance (59%ile)      77%ile      NaN         NaN
# 3     1 facilities/km distance (69%ile)      78%ile      NaN         NaN
# 4   1.2 facilities/km distance (74%ile)      24%ile      NaN         NaN
#
#    Shape_Length    Shape_Area  LocationName
# 0  13443.155206  6.040790e+06    1001020100
# 1  11917.089598  7.834160e+06    1001020100
# 2   7770.915121  2.900774e+06    1001020200
# 3   6506.804784  1.793332e+06    1001020200
# 4  11070.367848  5.461602e+06    1001020300
#
# [5 rows x 125 columns]

# %% [markdown]
# Getting rid of any rows with zero population

# %%
poll = poll[poll['ACSTOTPOP'] != 0]

# %% [markdown]
# Dropping columns not needed

# %%
poll = poll.drop(["OBJECTID", 'STATE_NAME', 'ID', 'REGION', 'Shape_Length', 'Shape_Area'], axis=1)
poll.head()
# Out:
#   ST_ABBREV  ACSTOTPOP     D_PM25_2  B_PM25_D2  P_PM25_D2    D_OZONE_2  \
# 0        AL        636  -492.025529          6       52.0 -1866.386370
# 1        AL       1287 -2053.083414          4       30.0 -7787.902602
# 2        AL        810  1846.126938          8       75.0  7002.783717
# 3        AL       1218  1392.075305          8       72.0  5280.461532
# 4        AL       2641  -769.374640          5       48.0 -2911.892606
#
#    B_OZONE_D2  P_OZONE_D2  D_DSLPM_2  B_DSLPM_D2  ...  T_LDPNT_D2  \
# 0           6        52.0 -14.148258           6  ...      31%ile
# 1           4        32.0 -59.036679           4  ...      20%ile
# 2           8        75.0  57.850440           8  ...      77%ile
# 3           8        71.0  43.622227           8  ...      83%ile
# 4           5        49.0 -28.752998           5  ...      42%ile
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# 3  0.076 facilities/km distance (81%ile)     83%ile
# 4  0.074 facilities/km distance (80%ile)     32%ile
#
#                                   T_PRMP  T_PRMP_D2  \
# 0  0.085 facilities/km distance (23%ile)     53%ile
# 1  0.074 facilities/km distance (17%ile)     42%ile
# 2  0.078 facilities/km distance (20%ile)     67%ile
# 3  0.087 facilities/km distance (24%ile)     66%ile
# 4   0.08 facilities/km distance (21%ile)     51%ile
#
#                                 T_PTSDF  T_PTSDF_D2  T_PWDIS  T_PWDIS_D2  \
# 0  0.59 facilities/km distance (57%ile)      38%ile      NaN         NaN
# 1  0.45 facilities/km distance (52%ile)      23%ile      NaN         NaN
# 2  0.65 facilities/km distance (59%ile)      77%ile      NaN         NaN
# 3     1 facilities/km distance (69%ile)      78%ile      NaN         NaN
# 4   1.2 facilities/km distance (74%ile)      24%ile      NaN         NaN
#
#    LocationName
# 0    1001020100
# 1    1001020100
# 2    1001020200
# 3    1001020200
# 4    1001020300
#
# [5 rows x 119 columns]

# %%
poll.head()
# Out:
#   ST_ABBREV  ACSTOTPOP     D_PM25_2  B_PM25_D2  P_PM25_D2    D_OZONE_2  \
# 0        AL        636  -492.025529          6       52.0 -1866.386370
# 1        AL       1287 -2053.083414          4       30.0 -7787.902602
# 2        AL        810  1846.126938          8       75.0  7002.783717
# 3        AL       1218  1392.075305          8       72.0  5280.461532
# 4        AL       2641  -769.374640          5       48.0 -2911.892606
#
#    B_OZONE_D2  P_OZONE_D2  D_DSLPM_2  B_DSLPM_D2  ...  T_LDPNT_D2  \
# 0           6        52.0 -14.148258           6  ...      31%ile
# 1           4        32.0 -59.036679           4  ...      20%ile
# 2           8        75.0  57.850440           8  ...      77%ile
# 3           8        71.0  43.622227           8  ...      83%ile
# 4           5        49.0 -28.752998           5  ...      42%ile
#
#                                   T_PNPL  T_PNPL_D2  \
# 0  0.071 facilities/km distance (79%ile)     40%ile
# 1  0.064 facilities/km distance (76%ile)     19%ile
# 2  0.069 facilities/km distance (78%ile)     85%ile
# 3  0.076 facilities/km distance (81%ile)     83%ile
# 4  0.074 facilities/km distance (80%ile)     32%ile
#
#                                   T_PRMP  T_PRMP_D2  \
# 0  0.085 facilities/km distance (23%ile)     53%ile
# 1  0.074 facilities/km distance (17%ile)     42%ile
# 2  0.078 facilities/km distance (20%ile)     67%ile
# 3  0.087 facilities/km distance (24%ile)     66%ile
# 4   0.08 facilities/km distance (21%ile)     51%ile
#
#                                 T_PTSDF  T_PTSDF_D2  T_PWDIS  T_PWDIS_D2  \
# 0  0.59 facilities/km distance (57%ile)      38%ile      NaN         NaN
# 1  0.45 facilities/km distance (52%ile)      23%ile      NaN         NaN
# 2  0.65 facilities/km distance (59%ile)      77%ile      NaN         NaN
# 3     1 facilities/km distance (69%ile)      78%ile      NaN         NaN
# 4   1.2 facilities/km distance (74%ile)      24%ile      NaN         NaN
#
#    LocationName
# 0    1001020100
# 1    1001020100
# 2    1001020200
# 3    1001020200
# 4    1001020300
#
# [5 rows x 119 columns]

# %%
df.columns.get_loc('DSLPM')
# Out:
# 45

# %% [markdown]
# Getting rid of map data

# %%
df = poll
pop = df.ACSTOTPOP
loc = df.LocationName
df = df.iloc[:, 1:67]

# %% [markdown]
# Multiplying numerical columns, except ACSTOTPOP, by population (ACSTOTPOP), as a step in the process of combining the numberical data of rows with same LocationName by a weighted average

# %%
df.head()
# Out:
#    ACSTOTPOP     D_PM25_2  B_PM25_D2  P_PM25_D2    D_OZONE_2  B_OZONE_D2  \
# 0        636  -492.025529          6       52.0 -1866.386370           6
# 1       1287 -2053.083414          4       30.0 -7787.902602           4
# 2        810  1846.126938          8       75.0  7002.783717           8
# 3       1218  1392.075305          8       72.0  5280.461532           8
# 4       2641  -769.374640          5       48.0 -2911.892606           5
#
#    P_OZONE_D2  D_DSLPM_2  B_DSLPM_D2  P_DSLPM_D2  ...  B_PNPL  P_PNPL  \
# 0        52.0 -14.148258           6        51.0  ...       8    79.0
# 1        32.0 -59.036679           4        30.0  ...       8    76.0
# 2        75.0  57.850440           8        76.0  ...       8    78.0
# 3        71.0  43.622227           8        72.0  ...       9    81.0
# 4        49.0 -28.752998           5        42.0  ...       9    80.0
#
#        PRMP  B_PRMP  P_PRMP     PTSDF  B_PTSDF  P_PTSDF  PWDIS  B_PWDIS
# 0  0.085201       3    23.0  0.586754        6     57.0    NaN        0
# 1  0.073796       2    17.0  0.450601        6     52.0    NaN        0
# 2  0.077868       3    20.0  0.653377        6     59.0    NaN        0
# 3  0.086918       3    24.0  1.009395        7     69.0    NaN        0
# 4  0.080274       3    21.0  1.177764        8     74.0    NaN        0
#
# [5 rows x 66 columns]

# %%
df = df.drop(['B_RESP', 'P_RESP', 'P_CANCR', 'B_CANCR', 'P_DSLPM', 'B_DSLPM', 'P_OZONE', 'B_OZONE', 'P_PM25', 'B_PM25','P_PWDIS_D2','B_PWDIS_D2', 'D_PWDIS_2','P_DSLPM_D2', 'B_DSLPM_D2','B_PWDIS','P_PTSDF', 'B_PTSDF','P_PRMP','B_PRMP','P_PNPL','B_PNPL','P_LDPNT','B_LDPNT','P_PTRAF','B_PTRAF','B_CANCR_D2'], axis=1)
df.head()
# Out:
#    ACSTOTPOP     D_PM25_2  B_PM25_D2  P_PM25_D2    D_OZONE_2  B_OZONE_D2  \
# 0        636  -492.025529          6       52.0 -1866.386370           6
# 1       1287 -2053.083414          4       30.0 -7787.902602           4
# 2        810  1846.126938          8       75.0  7002.783717           8
# 3       1218  1392.075305          8       72.0  5280.461532           8
# 4       2641  -769.374640          5       48.0 -2911.892606           5
#
#    P_OZONE_D2  D_DSLPM_2     D_CANCR_2  P_CANCR_D2  ...      OZONE     DSLPM  \
# 0        52.0 -14.148258  -2506.966483        51.0  ...  36.760212  0.278663
# 1        32.0 -59.036679 -10460.862287        27.0  ...  36.760212  0.278663
# 2        75.0  57.850440   9566.077321        77.0  ...  36.836966  0.304313
# 3        71.0  43.622227   7213.317639        73.0  ...  36.836966  0.304313
# 4        49.0 -28.752998  -4008.215270        46.0  ...  36.884999  0.364215
#
#       CANCER      RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# 0  49.377032  0.788052   91.015900    0.272109  0.070942  0.085201  0.586754
# 1  49.377032  0.788052    2.618744    0.115464  0.064344  0.073796  0.450601
# 2  50.320741  0.808744    4.679322    0.143243  0.069234  0.077868  0.653377
# 3  50.320741  0.808744  218.647491    0.342324  0.075614  0.086918  1.009395
# 4  50.772140  0.816773   69.644262    0.083889  0.073913  0.080274  1.177764
#
#    PWDIS
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['ACSTOTPOP', 'D_PM25_2', 'B_PM25_D2', 'P_PM25_D2', 'D_OZONE_2',
#        'B_OZONE_D2', 'P_OZONE_D2', 'D_DSLPM_2', 'D_CANCR_2', 'P_CANCR_D2',
#        'D_RESP_2', 'B_RESP_D2', 'P_RESP_D2', 'D_PTRAF_2', 'B_PTRAF_D2',
#        'P_PTRAF_D2', 'D_LDPNT_2', 'B_LDPNT_D2', 'P_LDPNT_D2', 'D_PNPL_2',
#        'B_PNPL_D2', 'P_PNPL_D2', 'D_PRMP_2', 'B_PRMP_D2', 'P_PRMP_D2',
#        'D_PTSDF_2', 'B_PTSDF_D2', 'P_PTSDF_D2', 'PM25', 'OZONE', 'DSLPM',
#        'CANCER', 'RESP', 'PTRAF', 'PRE1960PCT', 'PNPL', 'PRMP', 'PTSDF',
#        'PWDIS'],
#       dtype='object')

# %%
pop = df['ACSTOTPOP']

# %%
df = df.iloc[:,28:]

# %%
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS
# 0  0.070942  0.085201  0.586754    NaN
# 1  0.064344  0.073796  0.450601    NaN
# 2  0.069234  0.077868  0.653377    NaN
# 3  0.075614  0.086918  1.009395    NaN
# 4  0.073913  0.080274  1.177764    NaN

# %%
df['ACSTOTPOP'] = pop
df.head()
# Out:
#        PM25      OZONE     DSLPM     CANCER      RESP       PTRAF  PRE1960PCT  \
# 0  9.690899  36.760212  0.278663  49.377032  0.788052   91.015900    0.272109
# 1  9.690899  36.760212  0.278663  49.377032  0.788052    2.618744    0.115464
# 2  9.711240  36.836966  0.304313  50.320741  0.808744    4.679322    0.143243
# 3  9.711240  36.836966  0.304313  50.320741  0.808744  218.647491    0.342324
# 4  9.745683  36.884999  0.364215  50.772140  0.816773   69.644262    0.083889
#
#        PNPL      PRMP     PTSDF  PWDIS  ACSTOTPOP
# 0  0.070942  0.085201  0.586754    NaN        636
# 1  0.064344  0.073796  0.450601    NaN       1287
# 2  0.069234  0.077868  0.653377    NaN        810
# 3  0.075614  0.086918  1.009395    NaN       1218
# 4  0.073913  0.080274  1.177764    NaN       2641

# %%
for column in df:
    if column != 'ACSTOTPOP':
        df[column] *= df['ACSTOTPOP']

# %% [markdown]
# Adding back in LocationName

# %%
df['LocationName'] = loc

# %% [markdown]
# Grouping rows with same LocationName. Each numerical value is given the population-weighted mean

# %%
def mean_normed_by_pop(x):
    x = x.sum() / x['ACSTOTPOP'].sum()
    return x

df = df.groupby('LocationName', group_keys=False).apply(mean_normed_by_pop)

# %% [markdown]
# LocationName and ACSTOPOP were also normed, so they need to be dropped. The LocationName as the index is made into a column

# %%
df.drop(['LocationName', 'ACSTOTPOP'], axis=1, inplace=True)
df.reset_index(inplace=True)
df = df.rename(columns = {'index':'LocationName'})
df.head()
# Out:
#    LocationName      PM25      OZONE     DSLPM     CANCER      RESP  \
# 0    1001020100  9.690899  36.760212  0.278663  49.377032  0.788052
# 1    1001020200  9.711240  36.836966  0.304313  50.320741  0.808744
# 2    1001020300  9.745683  36.884999  0.364215  50.772140  0.816773
# 3    1001020400  9.761186  36.949586  0.447920  51.595926  0.835904
# 4    1001020500  9.791458  37.041363  0.499163  51.729998  0.841417
#
#         PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 0   31.854621    0.167272  0.066526  0.077568  0.495631  0.000000
# 1  133.186831    0.262809  0.073066  0.083303  0.867199  0.000000
# 2  183.972683    0.078924  0.075626  0.082494  1.528117  0.000000
# 3  448.339640    0.114548  0.084700  0.087962  2.299506  0.000000
# 4  198.171325    0.000000  0.094754  0.091258  1.635841  0.000005

# %%
df.tail()
# Out:
#        LocationName  PM25  OZONE     DSLPM     CANCER      RESP       PTRAF  \
# 73294   72153750501   0.0    0.0  0.053854  17.372062  0.260988   62.944027
# 73295   72153750502   0.0    0.0  0.058167  17.482087  0.260866  730.916547
# 73296   72153750503   0.0    0.0  0.049858  17.283555  0.258829  160.747911
# 73297   72153750601   0.0    0.0  0.055070  17.199448  0.258637   94.865143
# 73298   72153750602   0.0    0.0  0.057248  16.929739  0.256232  202.266125
#
#        PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 73294    0.009816  0.056186  0.720871  0.783596  0.020576
# 73295    0.072855  0.058919  0.851300  0.747859  0.024960
# 73296    0.067748  0.056212  0.604643  0.506445  0.006058
# 73297    0.061086  0.065172  1.636494  0.397525  0.016798
# 73298    0.167015  0.057998  0.557440  0.299630  0.000496

# %%
df.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/EJSCREEN_2020_interim.csv')

# %%
health_2022 = 'C:/Users/butle/hp/Capstone_Two/data/raw/PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2022_release.csv'
df2 = pd.read_csv(health_2022)

# %%
df2.head()
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2020        AL   Alabama    Autauga        1001    1001020200      BRFSS
# 1  2020        AL   Alabama    Autauga        1001    1001020400      BRFSS
# 2  2020        AL   Alabama    Autauga        1001    1001021000      BRFSS
# 3  2020        AL   Alabama    Baldwin        1003    1003010905      BRFSS
# 4  2020        AL   Alabama    Baldwin        1003    1003010906      BRFSS
#
#           Category                                            Measure  \
# 0  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 1  Health Outcomes               Obesity among adults aged >=18 years
# 2  Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Outcomes                Stroke among adults aged >=18 years
# 4  Health Outcomes            Depression among adults aged >=18 years
#
#   Data_Value_Unit  ... Data_Value_Footnote  Low_Confidence_Limit  \
# 0               %  ...                 NaN                   6.8
# 1               %  ...                 NaN                  31.5
# 2               %  ...                 NaN                  39.3
# 3               %  ...                 NaN                   2.7
# 4               %  ...                 NaN                  26.3
#
#    High_Confidence_Limit  TotalPopulation                       Geolocation  \
# 0                    8.5             2170  POINT (-86.47338874 32.47425254)
# 1                   35.0             4386  POINT (-86.44370417 32.47203959)
# 2                   41.2             2894  POINT (-86.75607371 32.60894544)
# 3                    3.2             8011  POINT (-87.75682132 30.53592075)
# 4                   28.9             4302  POINT (-87.68753351 30.56418914)
#
#    LocationID  CategoryID   MeasureId  DataValueTypeID Short_Question_Text
# 0  1001020200     HLTHOUT        COPD           CrdPrv                COPD
# 1  1001020400     HLTHOUT     OBESITY           CrdPrv             Obesity
# 2  1001021000     HLTHOUT     OBESITY           CrdPrv             Obesity
# 3  1003010905     HLTHOUT      STROKE           CrdPrv              Stroke
# 4  1003010906     HLTHOUT  DEPRESSION           CrdPrv          Depression
#
# [5 rows x 23 columns]

# %%
df2.shape
# Out:
# (2161543, 23)

# %%
df2.tail()
# Out:
#          Year StateAbbr  StateDesc CountyName  CountyFIPS  LocationName  \
# 2161538  2020        WI  Wisconsin   Waukesha       55133   55133204002
# 2161539  2020        WI  Wisconsin       Rock       55105   55105002700
# 2161540  2020        WI  Wisconsin   Waukesha       55133   55133203200
# 2161541  2020        WI  Wisconsin   Waukesha       55133   55133203101
# 2161542  2020        WI  Wisconsin   Waukesha       55133   55133200400
#
#         DataSource         Category  \
# 2161538      BRFSS       Prevention
# 2161539      BRFSS    Health Status
# 2161540      BRFSS  Health Outcomes
# 2161541      BRFSS       Prevention
# 2161542      BRFSS  Health Outcomes
#
#                                                    Measure Data_Value_Unit  \
# 2161538  Fecal occult blood test, sigmoidoscopy, or col...               %
# 2161539  Physical health not good for >=14 days among a...               %
# 2161540  Cancer (excluding skin cancer) among adults ag...               %
# 2161541  Visits to dentist or dental clinic among adult...               %
# 2161542  Chronic kidney disease among adults aged >=18 ...               %
#
#          ... Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# 2161538  ...                 NaN                  59.0                   64.9
# 2161539  ...                 NaN                   9.6                   11.6
# 2161540  ...                 NaN                   7.0                    7.8
# 2161541  ...                 NaN                  74.7                   80.6
# 2161542  ...                 NaN                   2.1                    2.5
#
#          TotalPopulation                       Geolocation   LocationID  \
# 2161538             5479   POINT (-88.4824858 42.88723077)  55133204002
# 2161539             2571    POINT (-89.24626648 42.548431)  55105002700
# 2161540             4106  POINT (-88.31331246 43.07069963)  55133203200
# 2161541             6536  POINT (-88.27895206 43.04127835)  55133203101
# 2161542             6582  POINT (-88.10191212 43.13413751)  55133200400
#
#          CategoryID     MeasureId  DataValueTypeID  \
# 2161538     PREVENT  COLON_SCREEN           CrdPrv
# 2161539    HLTHSTAT         PHLTH           CrdPrv
# 2161540     HLTHOUT        CANCER           CrdPrv
# 2161541     PREVENT        DENTAL           CrdPrv
# 2161542     HLTHOUT        KIDNEY           CrdPrv
#
#                  Short_Question_Text
# 2161538  Colorectal Cancer Screening
# 2161539              Physical Health
# 2161540         Cancer (except skin)
# 2161541                 Dental Visit
# 2161542       Chronic Kidney Disease
#
# [5 rows x 23 columns]

# %%
df2 = df2[df2['Category'] == 'Health Outcomes']

# %%
df2.shape
# Out:
# (936284, 23)

# %%
df[df['LocationName'] == 1001020200]
# Out:
#    LocationName     PM25      OZONE     DSLPM     CANCER      RESP  \
# 1    1001020200  9.71124  36.836966  0.304313  50.320741  0.808744
#
#         PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  PWDIS
# 1  133.186831    0.262809  0.073066  0.083303  0.867199    0.0

# %%
df[df['LocationName'] == 55133200400]
# Out:
#        LocationName      PM25     OZONE     DSLPM     CANCER      RESP  \
# 72123   55133200400  7.514909  43.06825  0.387525  22.748623  0.292665
#
#             PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF     PWDIS
# 72123  180.213938    0.221044  0.222978  1.888956  1.393416  0.011332

# %%
df2['LocationName'].isin(df['LocationName']).value_counts()
# Out:
# True     936104
# False       180
# Name: LocationName, dtype: int64

# %%
df['LocationName'].isin(df2['LocationName']).value_counts()
# Out:
# True     72323
# False      976
# Name: LocationName, dtype: int64

# %% [markdown]
# Not all of the LocationNames in the health data are present in the environmental data. Slicing the health database

# %%
common_rows_health = df2.loc[df2['LocationName'].isin(df['LocationName'])]
common_rows_health.head()
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2020        AL   Alabama    Autauga        1001    1001020200      BRFSS
# 1  2020        AL   Alabama    Autauga        1001    1001020400      BRFSS
# 2  2020        AL   Alabama    Autauga        1001    1001021000      BRFSS
# 3  2020        AL   Alabama    Baldwin        1003    1003010905      BRFSS
# 4  2020        AL   Alabama    Baldwin        1003    1003010906      BRFSS
#
#           Category                                            Measure  \
# 0  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 1  Health Outcomes               Obesity among adults aged >=18 years
# 2  Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Outcomes                Stroke among adults aged >=18 years
# 4  Health Outcomes            Depression among adults aged >=18 years
#
#   Data_Value_Unit  ... Data_Value_Footnote  Low_Confidence_Limit  \
# 0               %  ...                 NaN                   6.8
# 1               %  ...                 NaN                  31.5
# 2               %  ...                 NaN                  39.3
# 3               %  ...                 NaN                   2.7
# 4               %  ...                 NaN                  26.3
#
#    High_Confidence_Limit  TotalPopulation                       Geolocation  \
# 0                    8.5             2170  POINT (-86.47338874 32.47425254)
# 1                   35.0             4386  POINT (-86.44370417 32.47203959)
# 2                   41.2             2894  POINT (-86.75607371 32.60894544)
# 3                    3.2             8011  POINT (-87.75682132 30.53592075)
# 4                   28.9             4302  POINT (-87.68753351 30.56418914)
#
#    LocationID  CategoryID   MeasureId  DataValueTypeID Short_Question_Text
# 0  1001020200     HLTHOUT        COPD           CrdPrv                COPD
# 1  1001020400     HLTHOUT     OBESITY           CrdPrv             Obesity
# 2  1001021000     HLTHOUT     OBESITY           CrdPrv             Obesity
# 3  1003010905     HLTHOUT      STROKE           CrdPrv              Stroke
# 4  1003010906     HLTHOUT  DEPRESSION           CrdPrv          Depression
#
# [5 rows x 23 columns]

# %%
common_rows_health.shape
# Out:
# (936104, 23)

# %%
df3 = common_rows_health
df3.Category.nunique()
# Out:
# 1

# %%
df3.Category.unique()
# Out:
# array(['Health Outcomes'], dtype=object)

# %%
df3.shape
# Out:
# (936104, 23)

# %%
df3.DataSource.nunique()
# Out:
# 1

# %%
df3.DataSource.unique()
# Out:
# array(['BRFSS'], dtype=object)

# %%
df3.Data_Value_Footnote_Symbol.nunique()
# Out:
# 0

# %%
df3.Data_Value_Footnote.nunique()
# Out:
# 0

# %%
df3.DataValueTypeID.unique()
# Out:
# array(['CrdPrv'], dtype=object)

# %%
df3.DataValueTypeID.nunique()
# Out:
# 1

# %% [markdown]
# Getting rid of unnecessary columns

# %%
df3.head()
# Out:
#    Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName DataSource  \
# 0  2020        AL   Alabama    Autauga        1001    1001020200      BRFSS
# 1  2020        AL   Alabama    Autauga        1001    1001020400      BRFSS
# 2  2020        AL   Alabama    Autauga        1001    1001021000      BRFSS
# 3  2020        AL   Alabama    Baldwin        1003    1003010905      BRFSS
# 4  2020        AL   Alabama    Baldwin        1003    1003010906      BRFSS
#
#           Category                                            Measure  \
# 0  Health Outcomes  Chronic obstructive pulmonary disease among ad...
# 1  Health Outcomes               Obesity among adults aged >=18 years
# 2  Health Outcomes               Obesity among adults aged >=18 years
# 3  Health Outcomes                Stroke among adults aged >=18 years
# 4  Health Outcomes            Depression among adults aged >=18 years
#
#   Data_Value_Unit  ... Data_Value_Footnote  Low_Confidence_Limit  \
# 0               %  ...                 NaN                   6.8
# 1               %  ...                 NaN                  31.5
# 2               %  ...                 NaN                  39.3
# 3               %  ...                 NaN                   2.7
# 4               %  ...                 NaN                  26.3
#
#    High_Confidence_Limit  TotalPopulation                       Geolocation  \
# 0                    8.5             2170  POINT (-86.47338874 32.47425254)
# 1                   35.0             4386  POINT (-86.44370417 32.47203959)
# 2                   41.2             2894  POINT (-86.75607371 32.60894544)
# 3                    3.2             8011  POINT (-87.75682132 30.53592075)
# 4                   28.9             4302  POINT (-87.68753351 30.56418914)
#
#    LocationID  CategoryID   MeasureId  DataValueTypeID Short_Question_Text
# 0  1001020200     HLTHOUT        COPD           CrdPrv                COPD
# 1  1001020400     HLTHOUT     OBESITY           CrdPrv             Obesity
# 2  1001021000     HLTHOUT     OBESITY           CrdPrv             Obesity
# 3  1003010905     HLTHOUT      STROKE           CrdPrv              Stroke
# 4  1003010906     HLTHOUT  DEPRESSION           CrdPrv          Depression
#
# [5 rows x 23 columns]

# %%
df3.shape
# Out:
# (936104, 23)

# %%
df3.MeasureId.unique()
# Out:
# array(['COPD', 'OBESITY', 'STROKE', 'DEPRESSION', 'CASTHMA', 'TEETHLOST',
#        'ARTHRITIS', 'DIABETES', 'BPHIGH', 'CANCER', 'CHD', 'KIDNEY',
#        'HIGHCHOL'], dtype=object)

# %%
df3.drop(['StateDesc', 'Year', 'CountyFIPS', 'Geolocation', 'DataValueTypeID', 'Data_Value_Footnote','Data_Value_Footnote_Symbol', 'DataSource'], axis=1, inplace=True)
# Out:
# C:\Users\butle\AppData\Local\Temp\ipykernel_15896\1140354131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(['StateDesc', 'Year', 'CountyFIPS', 'Geolocation', 'DataValueTypeID', 'Data_Value_Footnote','Data_Value_Footnote_Symbol', 'DataSource'], axis=1, inplace=True)

# %%
df3.head()
# Out:
#   StateAbbr CountyName  LocationName         Category  \
# 0        AL    Autauga    1001020200  Health Outcomes
# 1        AL    Autauga    1001020400  Health Outcomes
# 2        AL    Autauga    1001021000  Health Outcomes
# 3        AL    Baldwin    1003010905  Health Outcomes
# 4        AL    Baldwin    1003010906  Health Outcomes
#
#                                              Measure Data_Value_Unit  \
# 0  Chronic obstructive pulmonary disease among ad...               %
# 1               Obesity among adults aged >=18 years               %
# 2               Obesity among adults aged >=18 years               %
# 3                Stroke among adults aged >=18 years               %
# 4            Depression among adults aged >=18 years               %
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence         7.6                   6.8                    8.5
# 1  Crude prevalence        33.2                  31.5                   35.0
# 2  Crude prevalence        40.3                  39.3                   41.2
# 3  Crude prevalence         2.9                   2.7                    3.2
# 4  Crude prevalence        27.6                  26.3                   28.9
#
#    TotalPopulation  LocationID CategoryID   MeasureId Short_Question_Text
# 0             2170  1001020200    HLTHOUT        COPD                COPD
# 1             4386  1001020400    HLTHOUT     OBESITY             Obesity
# 2             2894  1001021000    HLTHOUT     OBESITY             Obesity
# 3             8011  1003010905    HLTHOUT      STROKE              Stroke
# 4             4302  1003010906    HLTHOUT  DEPRESSION          Depression

# %%
df3 = df3.iloc[:, 2:]

# %%
df3.head()
# Out:
#    LocationName         Category  \
# 0    1001020200  Health Outcomes
# 1    1001020400  Health Outcomes
# 2    1001021000  Health Outcomes
# 3    1003010905  Health Outcomes
# 4    1003010906  Health Outcomes
#
#                                              Measure Data_Value_Unit  \
# 0  Chronic obstructive pulmonary disease among ad...               %
# 1               Obesity among adults aged >=18 years               %
# 2               Obesity among adults aged >=18 years               %
# 3                Stroke among adults aged >=18 years               %
# 4            Depression among adults aged >=18 years               %
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence         7.6                   6.8                    8.5
# 1  Crude prevalence        33.2                  31.5                   35.0
# 2  Crude prevalence        40.3                  39.3                   41.2
# 3  Crude prevalence         2.9                   2.7                    3.2
# 4  Crude prevalence        27.6                  26.3                   28.9
#
#    TotalPopulation  LocationID CategoryID   MeasureId Short_Question_Text
# 0             2170  1001020200    HLTHOUT        COPD                COPD
# 1             4386  1001020400    HLTHOUT     OBESITY             Obesity
# 2             2894  1001021000    HLTHOUT     OBESITY             Obesity
# 3             8011  1003010905    HLTHOUT      STROKE              Stroke
# 4             4302  1003010906    HLTHOUT  DEPRESSION          Depression

# %%
df3['Crude_prevalence'] = df3['Data_Value']

# %%
df3['Category'].unique()
# Out:
# array(['Health Outcomes'], dtype=object)

# %%
df3.shape
# Out:
# (936104, 14)

# %%
df3.head()
# Out:
#    LocationName         Category  \
# 0    1001020200  Health Outcomes
# 1    1001020400  Health Outcomes
# 2    1001021000  Health Outcomes
# 3    1003010905  Health Outcomes
# 4    1003010906  Health Outcomes
#
#                                              Measure Data_Value_Unit  \
# 0  Chronic obstructive pulmonary disease among ad...               %
# 1               Obesity among adults aged >=18 years               %
# 2               Obesity among adults aged >=18 years               %
# 3                Stroke among adults aged >=18 years               %
# 4            Depression among adults aged >=18 years               %
#
#     Data_Value_Type  Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# 0  Crude prevalence         7.6                   6.8                    8.5
# 1  Crude prevalence        33.2                  31.5                   35.0
# 2  Crude prevalence        40.3                  39.3                   41.2
# 3  Crude prevalence         2.9                   2.7                    3.2
# 4  Crude prevalence        27.6                  26.3                   28.9
#
#    TotalPopulation  LocationID CategoryID   MeasureId Short_Question_Text  \
# 0             2170  1001020200    HLTHOUT        COPD                COPD
# 1             4386  1001020400    HLTHOUT     OBESITY             Obesity
# 2             2894  1001021000    HLTHOUT     OBESITY             Obesity
# 3             8011  1003010905    HLTHOUT      STROKE              Stroke
# 4             4302  1003010906    HLTHOUT  DEPRESSION          Depression
#
#    Crude_prevalence
# 0               7.6
# 1              33.2
# 2              40.3
# 3               2.9
# 4              27.6

# %%
df3 = df3.drop(['Category', 'Measure','Data_Value_Unit','Data_Value','LocationID','CategoryID'],axis=1)

# %%
df3.head()
# Out:
#    LocationName   Data_Value_Type  Low_Confidence_Limit  \
# 0    1001020200  Crude prevalence                   6.8
# 1    1001020400  Crude prevalence                  31.5
# 2    1001021000  Crude prevalence                  39.3
# 3    1003010905  Crude prevalence                   2.7
# 4    1003010906  Crude prevalence                  26.3
#
#    High_Confidence_Limit  TotalPopulation   MeasureId Short_Question_Text  \
# 0                    8.5             2170        COPD                COPD
# 1                   35.0             4386     OBESITY             Obesity
# 2                   41.2             2894     OBESITY             Obesity
# 3                    3.2             8011      STROKE              Stroke
# 4                   28.9             4302  DEPRESSION          Depression
#
#    Crude_prevalence
# 0               7.6
# 1              33.2
# 2              40.3
# 3               2.9
# 4              27.6

# %%
df3.tail()
# Out:
#          LocationName   Data_Value_Type  Low_Confidence_Limit  \
# 2161530   55109120202  Crude prevalence                   1.6
# 2161532   56043000301  Crude prevalence                  17.3
# 2161536   55127001602  Crude prevalence                   5.6
# 2161540   55133203200  Crude prevalence                   7.0
# 2161542   55133200400  Crude prevalence                   2.1
#
#          High_Confidence_Limit  TotalPopulation   MeasureId  \
# 2161530                    1.9             5161      KIDNEY
# 2161532                   19.5             2665  DEPRESSION
# 2161536                    6.8             5643         CHD
# 2161540                    7.8             4106      CANCER
# 2161542                    2.5             6582      KIDNEY
#
#             Short_Question_Text  Crude_prevalence
# 2161530  Chronic Kidney Disease               1.7
# 2161532              Depression              18.4
# 2161536  Coronary Heart Disease               6.2
# 2161540    Cancer (except skin)               7.4
# 2161542  Chronic Kidney Disease               2.3

# %%
df3 = df3.drop(['Data_Value_Type', 'Short_Question_Text'], axis=1)

# %%
df3.columns
# Out:
# Index(['LocationName', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'TotalPopulation', 'MeasureId', 'Crude_prevalence'],
#       dtype='object')

# %%
col = df3.columns.to_list()
col
# Out:
# ['LocationName',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'TotalPopulation',
#  'MeasureId',
#  'Crude_prevalence']

# %%
cols = ['LocationName', 'MeasureId', 'Crude_prevalence','Low_Confidence_Limit', 'High_Confidence_Limit',  'TotalPopulation'  ]
cols
# Out:
# ['LocationName',
#  'MeasureId',
#  'Crude_prevalence',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'TotalPopulation']

# %%
df3 = df3[cols]
df3.columns
# Out:
# Index(['LocationName', 'MeasureId', 'Crude_prevalence', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'TotalPopulation'],
#       dtype='object')

# %%
df3.head()
# Out:
#    LocationName   MeasureId  Crude_prevalence  Low_Confidence_Limit  \
# 0    1001020200        COPD               7.6                   6.8
# 1    1001020400     OBESITY              33.2                  31.5
# 2    1001021000     OBESITY              40.3                  39.3
# 3    1003010905      STROKE               2.9                   2.7
# 4    1003010906  DEPRESSION              27.6                  26.3
#
#    High_Confidence_Limit  TotalPopulation
# 0                    8.5             2170
# 1                   35.0             4386
# 2                   41.2             2894
# 3                    3.2             8011
# 4                   28.9             4302

# %%
df3[df3['MeasureId'] == 'COPD'].shape
# Out:
# (72323, 6)

# %%
df3[df3['MeasureId'] == 'Obesity'].shape
# Out:
# (0, 6)

# %%
df3.MeasureId.unique()
# Out:
# array(['COPD', 'OBESITY', 'STROKE', 'DEPRESSION', 'CASTHMA', 'TEETHLOST',
#        'ARTHRITIS', 'DIABETES', 'BPHIGH', 'CANCER', 'CHD', 'KIDNEY',
#        'HIGHCHOL'], dtype=object)

# %%
outcomes = df3.copy()

# %%
combined = pd.merge(outcomes,df)
combined.rename({'LocationName': 'CensusTract', 'TotalPopulation':'TotalPopHealth',"CANCER": "AirToxicsRisk", 'DSLPM':'DieselPM'}, axis=1, inplace=True)
combined.head()
# Out:
#    CensusTract  MeasureId  Crude_prevalence  Low_Confidence_Limit  \
# 0   1001020200       COPD               7.6                   6.8
# 1   1001020200        CHD               5.9                   5.5
# 2   1001020200     BPHIGH              43.6                  42.3
# 3   1001020200  TEETHLOST              19.4                  14.4
# 4   1001020200     CANCER               5.0                   4.8
#
#    High_Confidence_Limit  TotalPopHealth     PM25      OZONE  DieselPM  \
# 0                    8.5            2170  9.71124  36.836966  0.304313
# 1                    6.3            2170  9.71124  36.836966  0.304313
# 2                   44.7            2170  9.71124  36.836966  0.304313
# 3                   25.0            2170  9.71124  36.836966  0.304313
# 4                    5.2            2170  9.71124  36.836966  0.304313
#
#    AirToxicsRisk      RESP       PTRAF  PRE1960PCT      PNPL      PRMP  \
# 0      50.320741  0.808744  133.186831    0.262809  0.073066  0.083303
# 1      50.320741  0.808744  133.186831    0.262809  0.073066  0.083303
# 2      50.320741  0.808744  133.186831    0.262809  0.073066  0.083303
# 3      50.320741  0.808744  133.186831    0.262809  0.073066  0.083303
# 4      50.320741  0.808744  133.186831    0.262809  0.073066  0.083303
#
#       PTSDF  PWDIS
# 0  0.867199    0.0
# 1  0.867199    0.0
# 2  0.867199    0.0
# 3  0.867199    0.0
# 4  0.867199    0.0

# %% [markdown]
# Re-indexing as CensusTract will not be a feature.

# %%
combined.set_index('CensusTract', inplace=True)

# %% [markdown]
# Making a separate dataframe for each health concern.

# %%
asthma = combined[combined['MeasureId'] == 'CASTHMA']
asthma = asthma.drop('MeasureId', axis = 1)
asthma = asthma.rename({'Crude_prevalence': "Asthma_prevalence"}, axis=1)
asthma.head()
# Out:
#              Asthma_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200                10.9                  10.4                   11.4
# 1001020400                 8.8                   8.4                    9.3
# 1001021000                10.3                  10.0                   10.6
# 1003010905                 9.4                   9.1                    9.8
# 1003010906                 9.9                   9.4                   10.5
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %%
asthma.shape
# Out:
# (72323, 15)

# %%
asthma.describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 asthma.describe
#
# NameError: name 'asthma' is not defined

# %%
kidney = combined[combined['MeasureId'] == 'KIDNEY']  
kidney = kidney.drop('MeasureId', axis = 1)
kidney = kidney.rename({'Crude_prevalence': "Kidney_prevalence"}, axis=1)
kidney.head()
# Out:
#              Kidney_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200                 3.1                   2.9                    3.3
# 1001020400                 2.9                   2.7                    3.2
# 1001021000                 3.3                   3.2                    3.4
# 1003010905                 2.7                   2.6                    2.9
# 1003010906                 3.3                   3.0                    3.6
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %%
kidney.shape
# Out:
# (72323, 15)

# %%
chd = combined[combined['MeasureId'] == 'CHD']  
chd = chd.drop('MeasureId', axis = 1)
chd = chd.rename({'Crude_prevalence': "CHD_prevalence"}, axis=1)
chd.head()
# Out:
#              CHD_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200              5.9                   5.5                    6.3
# 1001020400              7.1                   6.4                    7.9
# 1001021000              7.3                   7.0                    7.7
# 1003010905              6.4                   6.0                    6.8
# 1003010906              7.9                   7.2                    8.6
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %%
stroke = combined[combined['MeasureId'] == 'STROKE']
stroke = stroke.drop('MeasureId', axis = 1)
stroke = stroke.rename({'Crude_prevalence': "Stroke_prevalence"}, axis=1)
stroke.head()
# Out:
#              Stroke_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200                 3.7                   3.4                    4.1
# 1001020400                 3.0                   2.6                    3.5
# 1001021000                 3.8                   3.5                    4.0
# 1003010905                 2.9                   2.7                    3.2
# 1003010906                 3.7                   3.3                    4.2
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %%
cancer = combined[combined['MeasureId'] == 'CANCER']
cancer = cancer.drop('MeasureId', axis = 1)
cancer = cancer.rename({'Crude_prevalence': "Cancer_prevalence"}, axis=1)
cancer.head()
# Out:
#              Cancer_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200                 5.0                   4.8                    5.2
# 1001020400                 8.0                   7.5                    8.4
# 1001021000                 6.2                   6.0                    6.3
# 1003010905                 6.1                   5.9                    6.3
# 1003010906                 7.1                   6.7                    7.5
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %%
copd = combined[combined['MeasureId'] == 'COPD']
copd = copd.drop('MeasureId', axis = 1)
copd = copd.rename({'Crude_prevalence': "COPD_prevalence"}, axis=1)
copd.head()
# Out:
#              COPD_prevalence  Low_Confidence_Limit  High_Confidence_Limit  \
# CensusTract
# 1001020200               7.6                   6.8                    8.5
# 1001020400               7.2                   6.0                    8.6
# 1001021000               9.2                   8.5                    9.9
# 1003010905               7.8                   7.1                    8.6
# 1003010906               9.8                   8.6                   11.2
#
#              TotalPopHealth      PM25      OZONE  DieselPM  AirToxicsRisk  \
# CensusTract
# 1001020200             2170  9.711240  36.836966  0.304313      50.320741
# 1001020400             4386  9.761186  36.949586  0.447920      51.595926
# 1001021000             2894  9.292441  35.908669  0.160869      45.941855
# 1003010905             8011  8.402913  37.153641  0.233462      35.633327
# 1003010906             4302  8.414995  36.808459  0.249121      36.136884
#
#                  RESP       PTRAF  PRE1960PCT      PNPL      PRMP     PTSDF  \
# CensusTract
# 1001020200   0.808744  133.186831    0.262809  0.073066  0.083303  0.867199
# 1001020400   0.835904  448.339640    0.114548  0.084700  0.087962  2.299506
# 1001021000   0.733025    4.501463    0.166322  0.024765  0.222258  0.042577
# 1003010905   0.528960  224.749567    0.099045  0.020701  0.528059  0.078937
# 1003010906   0.539997  103.595218    0.063483  0.021972  0.614922  0.063767
#
#                     PWDIS
# CensusTract
# 1001020200   0.000000e+00
# 1001020400   0.000000e+00
# 1001021000   2.861655e-04
# 1003010905   1.444756e-04
# 1003010906   1.033556e-07

# %% [markdown]
# **Environmental risk columns defined**
#
# PM25 = PM2.5 level in air
#
# Ozone = Ozone level in air
#
# DieselPM = Diesel particulate matter level in air
#
# AirToxicsRisk = Air toxics cancer risk
#
# RESP = Air toxics respiratory hazard index
#
# PTRAF = Traffic proximity and volume
#
# PRE1960PCT = % pre-1960 housing (lead paint indicator)
#
# PNPL = Proximity to National Priorities List (NPL) [superfund] sites
#
# PRMP = Proximity to Risk Management Plan (RMP) facilities, facilities that use extremely
#        hazardous substances
#
# PTSDF = Proximity to Treatment Storage and Disposal (TSDF) facilities
#
# PWDIS = Indicator for major direct dischargers to water

# %% [markdown]
# Making a dataset for each health concern

# %%
copd.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/copd_data.csv')

# %%
asthma.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/asthma_data.csv')

# %%
stroke.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/stroke_data.csv')

# %%
cancer.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/cancer_data.csv')

# %%
chd.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/chd_data.csv')

# %%
kidney.to_csv('C:/Users/butle/hp/Capstone_Two/data/interim/kidney_data.csv')
