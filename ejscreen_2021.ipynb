# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ejscreen_2021 = 'C:/Users/butle/hp/environ_data/EJSCREEN_2021_StatePctile.csv'
df = pd.read_csv(ejscreen_2021)

# %%
df.head()
# Out:
#    OBJECTID            ID STATE_NAME ST_ABBREV  REGION  ACSTOTPOP  MINORPCT  \
# 0         1  1.001020e+10    Alabama        AL       4        730  0.169863
# 1         2  1.001020e+10    Alabama        AL       4       1263  0.166271
# 2         3  1.001020e+10    Alabama        AL       4        835  0.680240
# 3         4  1.001020e+10    Alabama        AL       4       1124  0.570285
# 4         5  1.001020e+10    Alabama        AL       4       2774  0.327325
#
#    LOWINCPCT  LESSHSPCT  LINGISOPCT  ...  \
# 0   0.382192   0.207843         0.0  ...
# 1   0.212985   0.073801         0.0  ...
# 2   0.546599   0.125230         0.0  ...
# 3   0.339891   0.162791         0.0  ...
# 4   0.214131   0.126368         0.0  ...
#
#                                 T_PTSDF  T_PTSDF_D2            T_OZONE  \
# 0  0.59 facilities/km distance (58%ile)      36%ile    37 ppb (24%ile)
# 1  0.45 facilities/km distance (53%ile)      24%ile    37 ppb (24%ile)
# ...

# %%
df.describe()
# Out:
#             OBJECTID            ID         REGION      ACSTOTPOP  \
# count  220333.000000  2.203330e+05  220333.000000  220333.000000
# mean   110167.000000  2.863577e+11       5.167642    1488.729523
# std     63604.802768  1.633201e+11       2.482247    1023.901679
# min         1.000000  1.001020e+10       1.000000       0.000000
# 25%     55084.000000  1.312100e+11       3.000000     887.000000
# 50%    110167.000000  2.816400e+11       5.000000    1266.000000
# 75%    165250.000000  4.200340e+11       7.000000    1822.000000
# max    220333.000000  7.215380e+11      10.000000   59947.000000
#
#             MINORPCT      LOWINCPCT      LESSHSPCT     LINGISOPCT  \
# count  220333.000000  220333.000000  220333.000000  220333.000000
# mean        0.379880       0.328999       0.127365       0.051343
# std         0.318703       0.213851       0.119135       0.110103
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
ejscreen_2021_columns = 'C:/Users/butle/hp/environ_data/2021_EJSCREEEN_columns-explained.xlsx'
columns = pd.read_excel(ejscreen_2021_columns)

# %%
columns.head()
# Out:
#   EJSCREEN Indexes Feature Class  -- EJSCREEN_Full in EJSCREEN_2021_USPR.gdb and EJSCREEN_2021_USPR.csv  \
# 0                                      Column Number
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#       Unnamed: 1                                Unnamed: 2
# 0  GDB Fieldname                               Description
# 1       OBJECTID  Unique ID for block group in geodatabase
# 2          Shape         Coordinates defining the features
# 3             ID          Census FIPS code for block group
# 4      ACSTOTPOP                          Total population

# %%
columns
# Out:
#     EJSCREEN Indexes Feature Class  -- EJSCREEN_Full in EJSCREEN_2021_USPR.gdb and EJSCREEN_2021_USPR.csv  \
# 0                                        Column Number
# 1                                                    1
# 2                                                    2
# 3                                                    3
# 4                                                    4
# ..                                                 ...
# 152                                                152
# 153                                                153
# 154                                                154
# 155                                                155
# 156                                                156
#
#         Unnamed: 1                                         Unnamed: 2
# 0    GDB Fieldname                                        Description
# 1         OBJECTID           Unique ID for block group in geodatabase
# ...
