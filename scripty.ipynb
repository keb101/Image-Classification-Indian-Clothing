# %%
import requests

# %%
res = requests.get('https://scotch.io')
print(res)
# Out:
# <Response [200]>

# %%
print(res.headers)
# Out:
# {'Date': 'Tue, 14 Mar 2023 22:32:06 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'last-modified': 'Mon, 13 Mar 2023 21:05:33 GMT', 'etag': 'W/"640f901d-31551"', 'expires': 'Tue, 14 Mar 2023 22:31:05 GMT', 'cache-control': 'max-age=0, public, max-age=0, s-maxage=300, must-revalidate', 'x-frame-options': 'DENY', 'x-xss-protection': '1; mode=block', 'CF-Cache-Status': 'HIT', 'Age': '61', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '7a7ff8827cf98cec-EWR', 'Content-Encoding': 'gzip'}

# %%
res.text
# Out:
# '<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charSet="utf-8"/><link rel="apple-touch-icon" sizes="180x180" href="/_next/static/media/apple-touch-icon.d7edaa01.png"/><link rel="icon" sizes="192x192" href="/_next/static/media/android-chrome-192x192.f09059d8.png"/><link rel="icon" sizes="512x512" href="/_next/static/media/android-chrome-512x512.5f2e6221.png"/><link rel="icon" type="image/png" sizes="32x32" href="/_next/static/media/favicon-32x32.b7ef9ede.png"/><link rel="icon" type="image/png" sizes="16x16" href="/_next/static/media/favicon-16x16.71c34517.png"/><link rel="icon" type="image/x-icon" href="/_next/static/media/favicon.594d6067.ico"/><meta name="viewport" content="minimum-scale=1, initial-scale=1, width=device-width, shrink-to-fit=no"/><meta name="twitter:card" content="summary"/><meta name="twitter:title" content="DigitalOcean"/><meta name="twitter:image" content="https://www.digitalocean.com/_next/static/media/social-share-default.e8530e9e.jpeg"/><meta property="o
# ...

# %%
url = 'https://translate.yandex.net/api/v1.5/tr.json/translate'
res = requests.get(url)

# %%
params = dict(key=API_KEY, text="గుడ్బై", lang='te-en')

# %%
res = requests.get(url, params=params)

# %%
res.text
# Out:
# '{"code":200,"lang":"te-en","text":["Goodbye"]}'

# %%
res.headers
# Out:
# {'Cache-Control': 'no-store', 'Content-Length': '46', 'Content-Type': 'application/json; charset=utf-8', 'Date': 'Tue, 14 Mar 2023 22:32:36 GMT', 'Set-Cookie': '_yasc=st8J6SURtUhi17kDZ1wA03oHW8LC6oou6MhVh6jFnVrFJt0MImsAmnnGT+Vv; domain=.yandex.net; path=/; expires=Fri, 11-Mar-2033 22:32:36 GMT; secure', 'X-Content-Type-Options': 'nosniff'}

# %%
json = res.json()
json
# Out:
# {'code': 200, 'lang': 'te-en', 'text': ['Goodbye']}

# %%
json['text']
# Out:
# ['Goodbye']

# %%
print(json['text'][0])
# Out:
# Goodbye

# %%
res.status_code
# Out:
# 200
