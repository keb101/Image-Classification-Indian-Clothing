# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime

# %%
df1 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2017_data.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 847039 entries, 0 to 847038
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    847039 non-null  int64
#  1   datetime      847039 non-null  object
#  2   network       845988 non-null  object
#  3   duration      845987 non-null  float64
#  4   network_info  845987 non-null  object
#  5   text          845986 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 38.8+ MB

# %%
df1["network"].unique()
# Out:
# array(['BBCNEWS', 'CNNW', 'FOXNEWSW', 'MSNBCW', nan,
#        "ICKER INVESTIGATES THE 'CREEPY PORN LAWYER' I. . \\u00a5 ...................."],
#       dtype=object)

# %%
df1["network"].isnull().value_counts()
# Out:
# False    845988
# True       1051
# Name: network, dtype: int64

# %%
lst = list(np.where(df1["network"].str.contains("ICKER") == True))
lst
# Out:
# [array([570068])]

# %%
df1.loc[570068]
# Out:
# Unnamed: 0                                                   1315
# datetime                                                        }
# network         ICKER INVESTIGATES THE 'CREEPY PORN LAWYER' I....
# duration                                                      NaN
# network_info                                                  NaN
# text                                                          NaN
# Name: 570068, dtype: object

# %%
df1.drop(570068, axis=0, inplace=True)

# %%
df1["network"].unique()
# Out:
# array(['BBCNEWS', 'CNNW', 'FOXNEWSW', 'MSNBCW', nan], dtype=object)

# %%
df1["network"].isnull().value_counts()
# Out:
# False    845987
# True       1051
# Name: network, dtype: int64

# %%
lst = df1[df1["network"].isnull()].index.tolist()
lst
# Out:
# [568753,
#  568754,
#  568755,
#  568756,
#  568757,
#  568758,
#  568759,
#  568760,
#  568761,
#  568762,
#  568763,
#  568764,
#  568765,
#  568766,
#  568767,
#  568768,
#  568769,
#  568770,
#  568771,
#  568772,
#  568773,
#  568774,
#  568775,
#  568776,
#  568777,
#  568778,
#  568779,
#  568780,
#  568781,
#  568782,
#  568783,
#  568784,
#  568785,
#  568786,
#  568787,
#  568788,
#  568789,
#  568790,
#  568791,
#  568792,
#  568793,
#  568794,
#  568795,
#  568796,
#  568797,
#  568798,
#  568799,
#  568800,
#  568801,
#  568802,
#  568803,
#  568804,
#  568805,
#  568806,
#  568807,
#  568808,
#  568809,
#  568810,
#  568811,
#  568812,
#  568813,
#  568814,
#  568815,
#  568816,
#  568817,
#  568818,
#  568819,
#  568820,
#  568821,
#  568822,
#  568823,
#  568824,
#  568825,
#  568826,
#  568827,
#  568828,
#  568829,
#  568830,
#  568831,
#  568832,
#  568833,
#  568834,
#  568835,
#  568836,
#  568837,
#  568838,
#  568839,
#  568840,
#  568841,
#  568842,
# ...

# %%
lst[0:5]
# Out:
# [568753, 568754, 568755, 568756, 568757]

# %%
df1.loc[[568753]]
# Out:
#         Unnamed: 0                                           datetime network  \
# 568753           0                                 'chan'   => [$c...     NaN
#
#         duration network_info text
# 568753       NaN          NaN  NaN

# %%
df1.iloc[568753, 1]
# Out:
# "                               'chan'   => [$ch=>1],"

# %%
df1.loc[[568754]]
# Out:
#         Unnamed: 0                                           datetime network  \
# 568754           1                                 'disk'   => '/'...     NaN
#
#         duration network_info text
# 568754       NaN          NaN  NaN

# %%
df1.iloc[568754, 1]
# Out:
# "                               'disk'   => '/'.$disks[ $n % count($disks) ],"

# %%
df1.loc[[568755]]
# Out:
#         Unnamed: 0                                           datetime network  \
# 568755           2                                 'freq'   => $freq,     NaN
#
#         duration network_info text
# 568755       NaN          NaN  NaN

# %%
lst[-5:-1]
# Out:
# [570063, 570064, 570065, 570066]

# %%
df1.loc[[570063]]
# Out:
#         Unnamed: 0                                           datetime network  \
# 570063        1310  function scan($ch = 'CSPAN', $only = FALSE, $h...     NaN
#
#         duration network_info text
# 570063       NaN          NaN  NaN

# %%
df1.iloc[570063, 1]
# Out:
# "function scan($ch = 'CSPAN', $only = FALSE, $hrsL = -24, $hrsR = 24, $maxB = 100) {"

# %%
df1.loc[[570066]]
# Out:
#         Unnamed: 0                    datetime network  duration network_info  \
# 570066        1313  function xml2tsv($xmlfi) {     NaN       NaN          NaN
#
#        text
# 570066  NaN

# %%
df1.iloc[570066, 1]
# Out:
# 'function xml2tsv($xmlfi) {'

# %%
df1.isnull().value_counts()
# Out:
# Unnamed: 0  datetime  network  duration  network_info  text
# False       False     False    False     False         False    845986
#                       True     True      True          True       1051
#                       False    False     False         True          1
# dtype: int64

# %%
df1 = df1.drop(index=lst)

# %%
df1.isnull().value_counts()
# Out:
# Unnamed: 0  datetime  network  duration  network_info  text
# False       False     False    False     False         False    845986
#                                                        True          1
# dtype: int64

# %%
lst1 = df1[df1["text"].isnull()].index.tolist()
lst1
# Out:
# [570036]

# %%
df1.loc[570036]
# Out:
# Unnamed: 0                     1283
# datetime        2018-05-15 04:59:00
# network                    FOXNEWSW
# duration                        8.0
# network_info         <?require @ia;
# text                            NaN
# Name: 570036, dtype: object

# %%
df1.drop(570036, axis=0, inplace=True)

# %%
df1.isnull().value_counts()
# Out:
# Unnamed: 0  datetime  network  duration  network_info  text
# False       False     False    False     False         False    845986
# dtype: int64

# %%
df1["network"].unique()
# Out:
# array(['BBCNEWS', 'CNNW', 'FOXNEWSW', 'MSNBCW'], dtype=object)

# %%
df2 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2018_data.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999186 entries, 0 to 999185
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    999186 non-null  int64
#  1   datetime      999186 non-null  object
#  2   network       999186 non-null  object
#  3   duration      999186 non-null  int64
#  4   network_info  999186 non-null  object
#  5   text          999186 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 45.7+ MB

# %%
df2["network"].unique()
# Out:
# array(['CNNW', 'FOXNEWSW', 'MSNBCW', 'BBCNEWS'], dtype=object)

# %%
df3 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2019_data.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2045 entries, 0 to 2044
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2045 non-null   int64
#  1   datetime      2045 non-null   object
#  2   network       2045 non-null   object
#  3   duration      2045 non-null   int64
#  4   network_info  2045 non-null   object
#  5   text          2045 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 96.0+ KB

# %%
df3["network"].unique()
# Out:
# array(['MSNBCW', 'CNNW', 'BBCNEWS', 'FOXNEWSW'], dtype=object)

# %%
df4 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2020_data.csv")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502722 entries, 0 to 502721
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    502722 non-null  int64
#  1   datetime      502720 non-null  object
#  2   network       502718 non-null  object
#  3   duration      502717 non-null  float64
#  4   network_info  490620 non-null  object
#  5   text          502716 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 23.0+ MB

# %%
df4.isnull().value_counts()
# Out:
# Unnamed: 0  datetime  network  duration  network_info  text
# False       False     False    False     False         False    490618
#                                          True          False     12097
#                       True     True      True          True          3
#                       False    False     False         True          1
#                                True      True          True          1
#             True      False    False     False         False         1
#                       True     True      True          True          1
# dtype: int64

# %%
lst4 = df4[df4["network_info"].isnull()].index.tolist()
lst4
# Out:
# [274414,
#  274417,
#  274419,
#  274423,
#  274425,
#  274427,
#  274430,
#  274433,
#  274436,
#  274437,
#  274438,
#  274440,
#  274443,
#  274446,
#  274448,
#  274451,
#  274453,
#  274455,
#  274457,
#  274459,
#  274464,
#  274467,
#  274470,
#  274475,
#  274488,
#  274492,
#  274496,
#  274500,
#  274506,
#  274510,
#  274512,
#  274515,
#  274519,
#  274522,
#  274545,
#  274548,
#  274552,
#  274555,
#  274559,
#  274561,
#  274564,
#  274567,
#  274570,
#  274573,
#  274575,
#  274579,
#  275049,
#  275051,
#  275055,
#  275056,
#  275060,
#  275066,
#  275069,
#  275073,
#  275077,
#  275080,
#  275082,
#  275085,
#  275088,
#  275091,
#  275094,
#  275097,
#  275112,
#  275115,
#  275122,
#  275125,
#  275128,
#  275130,
#  275133,
#  275136,
#  275139,
#  275142,
#  275145,
#  275147,
#  275149,
#  275810,
#  275811,
#  275822,
#  275824,
#  275829,
#  275886,
#  275889,
#  275899,
#  275901,
#  275908,
#  275916,
#  275917,
#  275919,
#  275936,
#  275941,
# ...

# %%
df4.loc[274515]
# Out:
# Unnamed: 0                         672
# datetime           2021-01-11 09:46:00
# network                        BBCNEWS
# duration                          29.0
# network_info                       NaN
# text            | maoneSIa plane crasn
# Name: 274515, dtype: object

# %%
df4.loc[294120]
# Out:
# Unnamed: 0                                                   2856
# datetime                                      2021-01-18 22:49:00
# network                                                   BBCNEWS
# duration                                                     10.0
# network_info                                                  NaN
# text            Jack Blanchard. UK Political Editor, Politico\...
# Name: 294120, dtype: object

# %%
df4.iloc[294120, 5]
# Out:
# 'Jack Blanchard. UK Political Editor, Politico\\nTHEPAPERS'

# %%
df4 = df4.dropna()

# %%
df4.isnull().value_counts()
# Out:
# Unnamed: 0  datetime  network  duration  network_info  text
# False       False     False    False     False         False    490618
# dtype: int64

# %%
df4["network"].unique()
# Out:
# array(['CNNW', 'BBCNEWS', 'MSNBCW', 'FOXNEWSW'], dtype=object)

# %%
df5 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2021_data.csv")
# Out:
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_7482/1279715756.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2021_data.csv")

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018326 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018326 non-null  int64
#  1   datetime      1018318 non-null  object
#  2   network       1018305 non-null  object
#  3   duration      1018295 non-null  object
#  4   network_info  978734 non-null   object
#  5   text          1018278 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 46.6+ MB

# %%
df5.head()
# Out:
#    Unnamed: 0             datetime network duration  \
# 0           0  2021-09-02 00:00:00    CNNW     28.0
# 1           1  2021-09-02 00:01:00    CNNW     38.0
# 2           2  2021-09-02 00:01:00  MSNBCW     33.0
# 3           3  2021-09-02 00:03:00    CNNW     32.0
# 4           4  2021-09-02 00:03:00  MSNBCW     45.0
#
#                                         network_info  \
# 0  CNNW_20210901_230000_Erin_Burnett_OutFront/sta...
# 1  CNNW_20210902_000000_Anderson_Cooper_360/start/60
# 2  MSNBCW_20210902_000000_All_In_With_Chris_Hayes...
# 3  CNNW_20210902_000000_Anderson_Cooper_360/start...
# 4  MSNBCW_20210902_000000_All_In_With_Chris_Hayes...
#
#                                                 text
# 0  WHITE SUPREMACIST PRAISE OF TALIBAN. TAKEOVER ...
# 1  WHITE SUPREMACIST PRAISE OF TALIBAN. TAKEOVER ...
# 2  . SUPREME COURT INACTION ALLOWS TEXAS. ANTI-AB...
# 3  U.S. OFFICIALS GRAPPLING WITH EXTREMISTS WHO. ...
# 4  . SUPREME COURT INACTION ALLOWS TEXAS. ANTI-AB...

# %%
df5["duration"].unique()
# Out:
# array(['28.0', '38.0', '33.0', '32.0', '45.0', '29.0', '55.0', '11.0',
#        '62.0', '50.0', '13.0', '9.0', '51.0', '42.0', '49.0', '17.0',
#        '30.0', '16.0', '43.0', '21.0', '39.0', '58.0', '24.0', '22.0',
#        '7.0', '60.0', '37.0', '40.0', '36.0', '4.0', '20.0', '8.0', '5.0',
#        '27.0', '25.0', '31.0', '26.0', '23.0', '19.0', '57.0', '3.0',
#        '48.0', '34.0', '56.0', '12.0', '59.0', '6.0', '18.0', '35.0',
#        '10.0', '14.0', '46.0', '53.0', '15.0', '41.0', '17529.0', '47.0',
#        '52.0', '54.0', '61.0', nan, '44.0', '63.0', '17528.0', '64.0',
#        '65.0',
#        "China lalwan contiict. Taiwan considers itself independent from China\\nChina laiwan contiict. China's President Xi vows reunification with island\\nChina laiwan contiict. President Xi's remarks come at time...",
#        '42', '24', '55', '43', '18', '30', '14', '53', '15', '62', '38',
#        '33', '37', '54', '36', '23', '12', '57', '44', '49', '11', '41',
# ...

# %%
lst = list(np.where(df5["duration"].str.contains("China") == True))
lst
# Out:
# [array([71631])]

# %%
df5.iloc[71631, :]
# Out:
# Unnamed: 0                                                      0
# datetime                                                        0
# network                BBCNEWS_20211010_030000_BBC_News/start/480
# duration        China lalwan contiict. Taiwan considers itself...
# network_info                                                  NaN
# text                                                          NaN
# Name: 71631, dtype: object

# %%
np.where(df5["duration"].str.contains("CNNW") == True)
# Out:
# (array([77132]),)

# %%
df5.iloc[77132,:]
# Out:
# Unnamed: 0                                                   2748
# datetime                                                     CNNW
# network                                                         7
# duration                     CNNW_20211011_010000_Diana/start/600
# network_info    Enroll today at. WellHealthSafety.com\nWellHea...
# text                                                          NaN
# Name: 77132, dtype: object

# %%
np.where(df5["duration"].str.contains("MSNBCW") == True)
# Out:
# (array([125736]),)

# %%
df5.iloc[77132,:]
# Out:
# Unnamed: 0                                                   2748
# datetime                                                     CNNW
# network                                                         7
# duration                     CNNW_20211011_010000_Diana/start/600
# network_info    Enroll today at. WellHealthSafety.com\nWellHea...
# text                                                          NaN
# Name: 77132, dtype: object

# %%
df5.drop([77132, 125736, 71631], axis=0,inplace=True)

# %%
df5["duration"].unique()
# Out:
# array(['28.0', '38.0', '33.0', '32.0', '45.0', '29.0', '55.0', '11.0',
#        '62.0', '50.0', '13.0', '9.0', '51.0', '42.0', '49.0', '17.0',
#        '30.0', '16.0', '43.0', '21.0', '39.0', '58.0', '24.0', '22.0',
#        '7.0', '60.0', '37.0', '40.0', '36.0', '4.0', '20.0', '8.0', '5.0',
#        '27.0', '25.0', '31.0', '26.0', '23.0', '19.0', '57.0', '3.0',
#        '48.0', '34.0', '56.0', '12.0', '59.0', '6.0', '18.0', '35.0',
#        '10.0', '14.0', '46.0', '53.0', '15.0', '41.0', '17529.0', '47.0',
#        '52.0', '54.0', '61.0', nan, '44.0', '63.0', '17528.0', '64.0',
#        '65.0', '42', '24', '55', '43', '18', '30', '14', '53', '15', '62',
#        '38', '33', '37', '54', '36', '23', '12', '57', '44', '49', '11',
#        '41', '31', '40', '45', '26', '50', '25', '27', '19', '13', '20',
#        '32', '9', '6', '10', '29', '7', '8', '17', '21', '28', '16', '48',
#        '39', '4', '5', '34', '3', '52', '63', '58', '47', '51', '22',
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018323 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018323 non-null  int64
#  1   datetime      1018315 non-null  object
#  2   network       1018302 non-null  object
#  3   duration      1018292 non-null  object
#  4   network_info  978732 non-null   object
#  5   text          1018278 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 54.4+ MB

# %%
df5["duration"] = df5["duration"].astype(float)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018323 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018323 non-null  int64
#  1   datetime      1018315 non-null  object
#  2   network       1018302 non-null  object
#  3   duration      1018292 non-null  float64
#  4   network_info  978732 non-null   object
#  5   text          1018278 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 54.4+ MB

# %%
df5["network"].unique()
# Out:
# array(['CNNW', 'MSNBCW', 'BBCNEWS', 'FOXNEWSW', nan, 'Browse by category',
#        'IDAHO HOSPITALS RATIONING TREATMENT AS COVID SURGES IN STATE',
#        '» CANDACE OWENS | \\"CANDACE\\" HOST\\n> CANDACE OWENS [ \\"CANDACE\\" HOST. IN THIS NEW RELIGION YOU MUST SWEAR\\n|. » CANDACE OWENS [ \\"CANDACE\\" HOST\\n» CANDACE OWENS [ \\"CANDACE\\"...',
#        '» BRET BAIER | \\"TO RESCUE THE REPUBLIC\\" AUTHOR\\n> BRET BAIER | \\"SPECIAL REPORT\\" ANCHOR\\nDEMOCRATS SEE WRITING ON THE WALL FOR THE MIDTERMS\\nULYSSES S. GRANT,. . e FRAGILE UNION, avo e...',
#        'Gracie Fllms/ZOth Television Animation. . pE@News\\nGracie Filrvls[ZOth Television Animation. . QE@NEWS',
#        "'m'mymth Friday15OO |\\n11 4. - Nadmet Saturday O5OO | |. oy\\n'm'Plymouth Saturday| |. o",
#        'FORMER DOJ OFFICIAL WHO PUSHED BASELESS ELECTION LIES. EXPECTED TO TESTIFY BEFORE JAN 6 COMMITTEE NEXT WEEK',
# ...

# %%
df5[df5["network"] == "IDAHO HOSPITALS RATIONING TREATMENT AS COVID SURGES IN STATE"]
# Out:
#        Unnamed: 0 datetime                                            network  \
# 38289           0      NaN  IDAHO HOSPITALS RATIONING TREATMENT AS COVID S...
#
#        duration network_info text
# 38289       NaN          NaN  NaN

# %%
lst5 = df5[df5["datetime"].isnull()].index.tolist()

# %%
df5.loc[21909]
# Out:
# Unnamed: 0                       0
# datetime                       NaN
# network         Browse by category
# duration                       NaN
# network_info                   NaN
# text                           NaN
# Name: 21909, dtype: object

# %%
df5.loc[109097]
# Out:
# Unnamed: 0        0
# datetime        NaN
# network         NaN
# duration        NaN
# network_info    NaN
# text            NaN
# Name: 109097, dtype: object

# %%
df5.drop(index=lst5, inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018315 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018315 non-null  int64
#  1   datetime      1018315 non-null  object
#  2   network       1018299 non-null  object
#  3   duration      1018292 non-null  float64
#  4   network_info  978732 non-null   object
#  5   text          1018278 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 54.4+ MB

# %%
lst5 = df5[df5["network"].isnull()].index.tolist()

# %%
lst5
# Out:
# [479,
#  8546,
#  32418,
#  38183,
#  46613,
#  64388,
#  71506,
#  74383,
#  74520,
#  85887,
#  88415,
#  91580,
#  102607,
#  115365,
#  117857,
#  118054]

# %%
df5.loc[479]
# Out:
# Unnamed: 0                                             0
# datetime        '\nUK social care: 1ax rise urged. UK...
# network                                              NaN
# duration                                             NaN
# network_info                                         NaN
# text                                                 NaN
# Name: 479, dtype: object

# %%
df5.loc[118054]
# Out:
# Unnamed: 0                                                      0
# datetime         represent actual clients. Actual client exper...
# network                                                       NaN
# duration                                                      NaN
# network_info                                                  NaN
# text                                                          NaN
# Name: 118054, dtype: object

# %%
df5.drop(index=lst5, inplace=True)
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018299 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018299 non-null  int64
#  1   datetime      1018299 non-null  object
#  2   network       1018299 non-null  object
#  3   duration      1018292 non-null  float64
#  4   network_info  978732 non-null   object
#  5   text          1018278 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 54.4+ MB

# %%
lst5 = df5[df5["text"].isnull()].index.tolist()
lst5
# Out:
# [10061,
#  28830,
#  38383,
#  50399,
#  53200,
#  56011,
#  56452,
#  58723,
#  68012,
#  71955,
#  80047,
#  80348,
#  85724,
#  85783,
#  103597,
#  105962,
#  115711,
#  117856,
#  125356,
#  126633,
#  126898]

# %%
df5.loc[10061]
# Out:
# Unnamed: 0                                        1515
# datetime                           2021-09-07 14:28:00
# network                                        BBCNEWS
# duration                                          11.0
# network_info    BBCNEWS_20210907_130000_BBC_News/start
# text                                               NaN
# Name: 10061, dtype: object

# %%
df5.loc[115711]
# Out:
# Unnamed: 0                                 345
# datetime                   2021-10-30 03:32:00
# network                                   CNNW
# duration                                  26.0
# network_info    CNNW_20211030_030000_Don_Lemon
# text                                       NaN
# Name: 115711, dtype: object

# %%
df5.drop(index=lst5, inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018278 entries, 0 to 1018325
# Data columns (total 6 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   Unnamed: 0    1018278 non-null  int64
#  1   datetime      1018278 non-null  object
#  2   network       1018278 non-null  object
#  3   duration      1018278 non-null  float64
#  4   network_info  978719 non-null   object
#  5   text          1018278 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 54.4+ MB

# %%
lst5 = df5[df5["network_info"].isnull()].index.tolist()

# %%
lst5
# Out:
# [7,
#  9,
#  11,
#  13,
#  16,
#  18,
#  21,
#  23,
#  26,
#  31,
#  33,
#  68,
#  70,
#  105,
#  108,
#  111,
#  113,
#  116,
#  119,
#  124,
#  127,
#  133,
#  141,
#  143,
#  146,
#  148,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  219,
#  220,
#  221,
#  224,
#  226,
#  249,
#  250,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  271,
#  274,
#  276,
#  278,
#  280,
#  284,
#  313,
#  314,
#  315,
#  317,
#  319,
#  322,
#  327,
#  330,
#  334,
#  337,
#  340,
#  344,
#  346,
#  348,
#  352,
#  355,
#  358,
#  360,
#  374,
#  376,
#  746,
#  751,
#  753,
#  755,
#  757,
#  759,
#  761,
#  762,
#  764,
#  766,
#  772,
#  773,
#  836,
#  839,
#  842,
#  845,
#  857,
#  861,
#  865,
#  868,
#  874,
#  903,
#  906,
#  908,
#  910,
#  915,
#  917,
#  919,
#  921,
#  923,
#  927,
#  930,
#  936,
#  939,
#  943,
#  947,
#  951,
#  974,
#  989,
#  993,
#  1003,
#  2477,
#  2479,
# ...

# %%
df5.loc[4946]
# Out:
# Unnamed: 0                                                    126
# datetime                                      2021-09-05 03:09:00
# network                                                   BBCNEWS
# duration                                                     18.0
# network_info                                                  NaN
# text            Lebanon power shortages. Syria agrees to help ...
# Name: 4946, dtype: object

# %%
df5.loc[7]
# Out:
# Unnamed: 0                                                      7
# datetime                                      2021-09-02 00:05:00
# network                                                   BBCNEWS
# duration                                                     11.0
# network_info                                                  NaN
# text            Alghanistan: Taliban in power. Taliban: New go...
# Name: 7, dtype: object

# %%
df6 = pd.read_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/raw/2022_data.csv")

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935926 entries, 0 to 935925
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    935926 non-null  int64
#  1   datetime      935926 non-null  object
#  2   network       935926 non-null  object
#  3   duration      935926 non-null  int64
#  4   network_info  921359 non-null  object
#  5   text          935926 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 42.8+ MB

# %%
df6["network"].unique()
# Out:
# array(['CNNW', 'FOXNEWSW', 'MSNBCW', 'BBCNEWS'], dtype=object)

# %%
lst6 = df6[df6["network_info"].isnull()].index.tolist()
lst6[:5]
# Out:
# [1733, 1735, 1737, 1738, 1741]

# %%
df6.loc[1733]
# Out:
# Unnamed: 0                             1733
# datetime                2022-09-02 19:46:00
# network                             BBCNEWS
# duration                                 15
# network_info                            NaN
# text            [o]e]c VAT\n|. [8]e]c [YATS
# Name: 1733, dtype: object

# %%
lst6[-5:]
# Out:
# [935882, 935884, 935887, 935895, 935900]

# %%
df6.loc[935900]
# Out:
# Unnamed: 0                     2838
# datetime        2023-07-02 23:46:00
# network                     BBCNEWS
# duration                         10
# network_info                    NaN
# text                     . [O ENEWS
# Name: 935900, dtype: object

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6])

# %%
df.head()
# Out:
#    Unnamed: 0             datetime   network  duration  \
# 0           0  2017-09-07 00:53:00   BBCNEWS      17.0
# 1           1  2017-09-07 01:04:00      CNNW      27.0
# 2           2  2017-09-07 01:04:00  FOXNEWSW      34.0
# 3           3  2017-09-07 01:05:00      CNNW      23.0
# 4           4  2017-09-07 01:05:00  FOXNEWSW       7.0
#
#                                         network_info  \
# 0      BBCNEWS_20170907_004500_Sport_Today/start/480
# 1  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 2        FOXNEWSW_20170907_010000_The_Five/start/240
# 3  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 4        FOXNEWSW_20170907_010000_The_Five/start/300
#
#                                                 text
# 0     JASON HOLDER. West Indies Captain\nSPORT TODAV
# 1  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...
# 2    PRES TRUMP: NO SECOND THOUGHTS ON DACA DECISION
# 3  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0             datetime   network  duration  \
# 935921        2859  2023-07-02 23:57:00      CNNW      10.0
# 935922        2860  2023-07-02 23:57:00  FOXNEWSW      34.0
# 935923        2861  2023-07-02 23:58:00      CNNW      26.0
# 935924        2862  2023-07-02 23:59:00      CNNW      28.0
# 935925        2863  2023-07-02 23:59:00  FOXNEWSW       8.0
#
#                                              network_info  \
# 935921  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935922  FOXNEWSW_20230702_230000_The_Big_Weekend_Show/...
# 935923  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935924  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935925  FOXNEWSW_20230702_230000_The_Big_Weekend_Show/...
#
#                                                      text
# 935921                                    Mre in San Frai
# 935922  MAN'S BEST FRIEND. DOG COLLECTS FRISBEES TO RA...
# 935923  2 DEAD, 28 INJURED DURING BALTIMORE BLOCK PART...
# ...

# %%
df.shape
# Out:
# (4292039, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4292039 entries, 0 to 935925
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Unnamed: 0    int64
#  1   datetime      object
#  2   network       object
#  3   duration      float64
#  4   network_info  object
#  5   text          object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 229.2+ MB

# %%
df["datetime"].unique()
# Out:
# array(['2017-09-07 00:53:00', '2017-09-07 01:04:00',
#        '2017-09-07 01:05:00', ..., '2023-07-02 23:57:00',
#        '2023-07-02 23:58:00', '2023-07-02 23:59:00'], dtype=object)

# %%
df["network"].unique()
# Out:
# array(['BBCNEWS', 'CNNW', 'FOXNEWSW', 'MSNBCW'], dtype=object)

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#               datetime   network  duration  \
# 0  2017-09-07 00:53:00   BBCNEWS      17.0
# 1  2017-09-07 01:04:00      CNNW      27.0
# 2  2017-09-07 01:04:00  FOXNEWSW      34.0
# 3  2017-09-07 01:05:00      CNNW      23.0
# 4  2017-09-07 01:05:00  FOXNEWSW       7.0
#
#                                         network_info  \
# 0      BBCNEWS_20170907_004500_Sport_Today/start/480
# 1  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 2        FOXNEWSW_20170907_010000_The_Five/start/240
# 3  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 4        FOXNEWSW_20170907_010000_The_Five/start/300
#
#                                                 text
# 0     JASON HOLDER. West Indies Captain\nSPORT TODAV
# 1  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...
# 2    PRES TRUMP: NO SECOND THOUGHTS ON DACA DECISION
# 3  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...
# 4  PRES TRUMP: TIME FOR CONGRE\u00a7\u00a7 TO TAC...

# %%
df.tail()
# Out:
#                    datetime   network  duration  \
# 935921  2023-07-02 23:57:00      CNNW      10.0
# 935922  2023-07-02 23:57:00  FOXNEWSW      34.0
# 935923  2023-07-02 23:58:00      CNNW      26.0
# 935924  2023-07-02 23:59:00      CNNW      28.0
# 935925  2023-07-02 23:59:00  FOXNEWSW       8.0
#
#                                              network_info  \
# 935921  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935922  FOXNEWSW_20230702_230000_The_Big_Weekend_Show/...
# 935923  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935924  CNNW_20230702_230000_CNN_Newsroom_With_Jim_Aco...
# 935925  FOXNEWSW_20230702_230000_The_Big_Weekend_Show/...
#
#                                                      text
# 935921                                    Mre in San Frai
# 935922  MAN'S BEST FRIEND. DOG COLLECTS FRISBEES TO RA...
# 935923  2 DEAD, 28 INJURED DURING BALTIMORE BLOCK PART...
# 935924  SRIRACHA SHORTAGE BOOSTS VALUE TO $7O A BOTTLE...
# ...

# %%
lst_climate_change = list(np.where(df["text"].str.contains("(?i)climate change") == True))

# %%
lst_global_warming = list(np.where(df["text"].str.contains("(?i)global warming") == True))

# %%
lst_climate = list(np.where(df["text"].str.contains("(?i)climate") == True))

# %%
len(lst_climate_change[0]), len(lst_global_warming[0]), len(lst_climate[0])
# Out:
# (9350, 648, 19603)

# %%
lst_global_warming = lst_global_warming[0]

# %%
lst_climate = lst_climate[0]

# %%
lst_global_heating = list(np.where(df["text"].str.contains("(?i)global heating") == True))

# %%
lst_global_heating
# Out:
# [array([1880311, 1880391, 1880481, 1880486, 2290595, 2291178, 2324725,
#         3264660, 3264664, 3264963, 3265094])]

# %%
lst_global_heating = lst_global_heating[0]

# %%
len(lst_global_heating)
# Out:
# 11

# %%
lst_greenhouse_gas = list(np.where(df["text"].str.contains("(?i)greenhouse gas") == True))

# %%
lst_greenhouse_gas = lst_greenhouse_gas[0]

# %%
len(lst_greenhouse_gas)
# Out:
# 250

# %%
greenhouse_gas = set(lst_greenhouse_gas)

# %%
global_heating = set(lst_global_heating)

# %%
climate = set(lst_climate)

# %%
global_warming = set(lst_global_warming)

# %%
climate = [x for x in lst_climate if x not in lst_global_heating if x not in lst_greenhouse_gas if x not in lst_global_warming]

# %%
len(climate)
# Out:
# 19182

# %%
global_heating = [x for x in lst_global_heating if x not in climate if x not in lst_global_warming if x not in lst_greenhouse_gas]
len(global_heating)
# Out:
# 10

# %%
global_warming = [x for x in lst_global_warming if x not in lst_global_heating if x not in lst_greenhouse_gas if x not in lst_climate]
len(global_warming)
# Out:
# 359

# %%
greenhouse_gas = [x for x in lst_greenhouse_gas if x not in lst_global_heating if x not in lst_global_warming if x not in lst_climate]
len(greenhouse_gas)
# Out:
# 116

# %%
all_words = climate + global_heating + global_warming + greenhouse_gas
len(all_words)
# Out:
# 19667

# %%
all_words.sort()
all_words
# Out:
# [1953,
#  2118,
#  2177,
#  3153,
#  9621,
#  9623,
#  10994,
#  10996,
#  10997,
#  10999,
#  11123,
#  11124,
#  11126,
#  11665,
#  11667,
#  11669,
#  11671,
#  11673,
#  11675,
#  11733,
#  11738,
#  11740,
#  11746,
#  11793,
#  11853,
#  11911,
#  11939,
#  12479,
#  13452,
#  13455,
#  13456,
#  13459,
#  13462,
#  13605,
#  13608,
#  13610,
#  13611,
#  14248,
#  14331,
#  14339,
#  14340,
#  14341,
#  14342,
#  14343,
#  14347,
#  14349,
#  15142,
#  15144,
#  15261,
#  15265,
#  15270,
#  16217,
#  16231,
#  16233,
#  16496,
#  16655,
#  16657,
#  16659,
#  16665,
#  16667,
#  16888,
#  17242,
#  19447,
#  19451,
#  21974,
#  21977,
#  25768,
#  25892,
#  25894,
#  25935,
#  25951,
#  25954,
#  26101,
#  26103,
#  26105,
#  26108,
#  26110,
#  26111,
#  26240,
#  26242,
#  26296,
#  26298,
#  26300,
#  26302,
#  26303,
#  26304,
#  26330,
#  26331,
#  26430,
#  26431,
#  26433,
#  26434,
#  26435,
#  26750,
#  26825,
#  26879,
#  26898,
#  26900,
#  26902,
#  26906,
# ...

# %%
all_words_df = df[df.index.isin(all_words)]

# %%
all_words_df.head()
# Out:
#                  datetime  network  duration  \
# 1953  2017-09-07 17:10:00  BBCNEWS       5.0
# 2118  2017-09-07 18:37:00  BBCNEWS       4.0
# 2177  2017-09-07 19:13:00  BBCNEWS       4.0
# 3153  2017-09-08 04:35:00  BBCNEWS       8.0
# 9621  2017-09-11 10:52:00  BBCNEWS      21.0
#
#                                            network_info  \
# 1953  BBCNEWS_20170907_170000_BBC_News_at_Six/start/600
# 2118        BBCNEWS_20170907_180000_BBC_News/start/2220
# 2177         BBCNEWS_20170907_190000_BBC_News/start/780
# 3153  BBCNEWS_20170908_043000_World_Business_Report/...
# 9621  BBCNEWS_20170911_100000_BBC_Newsroom_Live/star...
#
#                                                    text
# 1953  Dr DANN MITCHELL. Climate Scientist, Bristol U...
# 2118  Dr DANN MITCHELL. Climate Scientist, Bristol U...
# 2177  Dr DANN MITCHELL. Climate Scientist, Bristol U...
# 3153  HURRICANE COSTS. Irma expected to be among cos...
# 9621  UK ECONOMIC OUTLOOK. ICAEW says investment cli...

# %%
all_words_df["datetime"] = pd.to_datetime(all_words_df["datetime"])
all_words_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5332 entries, 1953 to 935021
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      5332 non-null   datetime64[ns]
#  1   network       5332 non-null   object
#  2   duration      5332 non-null   float64
#  3   network_info  5266 non-null   object
#  4   text          5332 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 249.9+ KB
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_7482/4024157511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_words_df["datetime"] = pd.to_datetime(all_words_df["datetime"])

# %%
all_words_df["date"] = all_words_df["datetime"].dt.strftime("%Y-%m-%d")
# Out:
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_7482/2714751511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_words_df["date"] = all_words_df["datetime"].dt.strftime("%Y-%m-%d")

# %%
all_words_df.head()
# Out:
#                 datetime  network  duration  \
# 1953 2017-09-07 17:10:00  BBCNEWS       5.0
# 2118 2017-09-07 18:37:00  BBCNEWS       4.0
# 2177 2017-09-07 19:13:00  BBCNEWS       4.0
# 3153 2017-09-08 04:35:00  BBCNEWS       8.0
# 9621 2017-09-11 10:52:00  BBCNEWS      21.0
#
#                                            network_info  \
# 1953  BBCNEWS_20170907_170000_BBC_News_at_Six/start/600
# 2118        BBCNEWS_20170907_180000_BBC_News/start/2220
# 2177         BBCNEWS_20170907_190000_BBC_News/start/780
# 3153  BBCNEWS_20170908_043000_World_Business_Report/...
# 9621  BBCNEWS_20170911_100000_BBC_Newsroom_Live/star...
#
#                                                    text        date
# 1953  Dr DANN MITCHELL. Climate Scientist, Bristol U...  2017-09-07
# 2118  Dr DANN MITCHELL. Climate Scientist, Bristol U...  2017-09-07
# 2177  Dr DANN MITCHELL. Climate Scientist, Bristol U...  2017-09-07
# 3153  HURRICANE COSTS. Irma expected to be among cos...  2017-09-08
# ...

# %%
all_words_df["date"].nunique()
# Out:
# 809

# %%
all_words_df.shape
# Out:
# (5332, 6)

# %%
all_words_df["date"].nunique()
# Out:
# 809

# %%
all_words_df.tail()
# Out:
#                   datetime  network  duration  \
# 932980 2023-07-01 23:23:00     CNNW      44.0
# 934226 2023-07-02 11:32:00     CNNW      39.0
# 934228 2023-07-02 11:33:00     CNNW      42.0
# 935019 2023-07-02 17:06:00     CNNW      43.0
# 935021 2023-07-02 17:07:00  BBCNEWS      21.0
#
#                                              network_info  \
# 932980  CNNW_20230701_230000_CNN_Newsroom_With_Jim_Aco...
# 934226  CNNW_20230702_110000_CNN_This_Morning_Weekend/...
# 934228  CNNW_20230702_110000_CNN_This_Morning_Weekend/...
# 935019  CNNW_20230702_170000_Fareed_Zakaria_GPS/start/360
# 935021                                                NaN
#
#                                                      text        date
# 932980  SOURCES: SPECIAL COUNSEL'S OFFICE STILL. INVES...  2023-07-01
# 934226  Py | INTERIOR MINISTRY: 7OO+ DETAINED IN FIFTH...  2023-07-02
# 934228  3 | MAYOR OF PARIS SUBURB SAYS HIS HOME WAS AT...  2023-07-02
# ...

# %%
df["datetime"] = pd.to_datetime(df["datetime"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4292039 entries, 0 to 935925
# Data columns (total 5 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   datetime      datetime64[ns]
#  1   network       object
#  2   duration      float64
#  3   network_info  object
#  4   text          object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 196.5+ MB

# %%
df["date"] = df["datetime"].dt.strftime("%Y-%m-%d")

# %%
df.head()
# Out:
#              datetime   network  duration  \
# 0 2017-09-07 00:53:00   BBCNEWS      17.0
# 1 2017-09-07 01:04:00      CNNW      27.0
# 2 2017-09-07 01:04:00  FOXNEWSW      34.0
# 3 2017-09-07 01:05:00      CNNW      23.0
# 4 2017-09-07 01:05:00  FOXNEWSW       7.0
#
#                                         network_info  \
# 0      BBCNEWS_20170907_004500_Sport_Today/start/480
# 1  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 2        FOXNEWSW_20170907_010000_The_Five/start/240
# 3  CNNW_20170907_010000_Anderson_Cooper_360/start...
# 4        FOXNEWSW_20170907_010000_The_Five/start/300
#
#                                                 text        date
# 0     JASON HOLDER. West Indies Captain\nSPORT TODAV  2017-09-07
# 1  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...  2017-09-07
# 2    PRES TRUMP: NO SECOND THOUGHTS ON DACA DECISION  2017-09-07
# 3  CATEGORY 5 IRMA BARRELS TOWARD FLORIDA; HURRIC...  2017-09-07
# ...

# %%
df["date"].nunique()
# Out:
# 1612

# %%
all_words_df.to_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/interim/third_eye_climate_words.csv")

# %%
df.to_csv("/Users/butler/Documents/GitHub/projects/tweets_climate_change/data/interim/third_eye_data.csv")
