# %%
import pandas as pd
import numpy as np
from datetime import datetime
import symspellpy

# %%
df_fox = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/FOXNEWS.200907.csv')

# %%
df_fox.head()
# Out:
#                                                  URL       MatchDateTime  \
# 0  https://archive.org/details/FOXNEWS_20090725_1...  7/25/2009 15:14:00
# 1  https://archive.org/details/FOXNEWS_20090710_0...   7/10/2009 8:10:52
# 2  https://archive.org/details/FOXNEWS_20090709_0...    7/9/2009 4:24:29
# 3  https://archive.org/details/FOXNEWS_20090710_0...   7/10/2009 9:15:41
# 4  https://archive.org/details/FOXNEWS_20090708_2...   7/8/2009 22:05:25
#
#    Station                            Show  \
# 0  FOXNEWS                   Forbes on FOX
# 1  FOXNEWS  Special Report With Bret Baier
# 2  FOXNEWS                         Hannity
# 3  FOXNEWS              The OReilly Factor
# 4  FOXNEWS  Special Report With Bret Baier
#
#                                             IAShowID  \
# 0              FOXNEWS_20090725_150000_Forbes_on_FOX
# 1  FOXNEWS_20090710_080000_Special_Report_With_Br...
# 2                    FOXNEWS_20090709_040000_Hannity
# ...

# %%
lst = pd.date_range(start='2009-07',end='2020-01', freq='MS')

# %%
lst[:10]
# Out:
# DatetimeIndex(['2009-07-01', '2009-08-01', '2009-09-01', '2009-10-01',
#                '2009-11-01', '2009-12-01', '2010-01-01', '2010-02-01',
#                '2010-03-01', '2010-04-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
lst[-10:]
# Out:
# DatetimeIndex(['2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01',
#                '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01',
#                '2019-12-01', '2020-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
d = pd.DataFrame()

# %%
d['dates'] = lst

# %%
d['dates'] = d['dates'].dt.strftime('%Y%m')

# %%
d.loc[1]
# Out:
# dates    200908
# Name: 1, dtype: object

# %%
old_file = '/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/FOXNEWS.200907.csv'
old_date = '200907'
for x in range(1, len(lst)):
    date = d.iloc[x,0]
    new_file = old_file.replace(old_date, date)
    df = pd.read_csv(new_file)
    df_fox = pd.concat([df_fox, df], axis=0)

# %%
df_fox.head()
# Out:
#                                                  URL       MatchDateTime  \
# 0  https://archive.org/details/FOXNEWS_20090725_1...  7/25/2009 15:14:00
# 1  https://archive.org/details/FOXNEWS_20090710_0...   7/10/2009 8:10:52
# 2  https://archive.org/details/FOXNEWS_20090709_0...    7/9/2009 4:24:29
# 3  https://archive.org/details/FOXNEWS_20090710_0...   7/10/2009 9:15:41
# 4  https://archive.org/details/FOXNEWS_20090708_2...   7/8/2009 22:05:25
#
#    Station                            Show  \
# 0  FOXNEWS                   Forbes on FOX
# 1  FOXNEWS  Special Report With Bret Baier
# 2  FOXNEWS                         Hannity
# 3  FOXNEWS              The OReilly Factor
# 4  FOXNEWS  Special Report With Bret Baier
#
#                                             IAShowID  \
# 0              FOXNEWS_20090725_150000_Forbes_on_FOX
# 1  FOXNEWS_20090710_080000_Special_Report_With_Br...
# 2                    FOXNEWS_20090709_040000_Hannity
# ...

# %%
df_fox.tail()
# Out:
#                                                    URL       MatchDateTime  \
# 149  https://archive.org/details/FOXNEWSW_20200116_...  1/16/2020 11:00:05
# 150  https://archive.org/details/FOXNEWSW_20200107_...   1/7/2020 21:43:29
# 151  https://archive.org/details/FOXNEWSW_20200109_...    1/9/2020 7:35:54
# 152  https://archive.org/details/FOXNEWSW_20200121_...   1/21/2020 8:33:40
# 153  https://archive.org/details/FOXNEWSW_20200121_...   1/21/2020 8:36:48
#
#      Station                                  Show  \
# 149  FOXNEWS                       FOX and Friends
# 150  FOXNEWS           Your World With Neil Cavuto
# 151  FOXNEWS                    The Ingraham Angle
# 152  FOXNEWS  Fox News at Night With Shannon Bream
# 153  FOXNEWS  Fox News at Night With Shannon Bream
#
#                                               IAShowID  \
# 149           FOXNEWSW_20200116_110000_FOX_and_Friends
# 150  FOXNEWSW_20200107_210000_Your_World_With_Neil_...
# ...

# %%
df_fox.shape
# Out:
# (25865, 7)

# %%
df_cnn = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/CNN.200907.csv')

# %%
df_cnn.head()
# Out:
#                                                  URL       MatchDateTime  \
# 0  https://archive.org/details/CNN_20090709_13000...   7/9/2009 13:06:28
# 1  https://archive.org/details/CNN_20090708_20000...   7/8/2009 22:43:10
# 2  https://archive.org/details/CNN_20090709_20000...   7/9/2009 20:02:25
# 3  https://archive.org/details/CNN_20090729_20000...  7/29/2009 22:10:10
# 4  https://archive.org/details/CNN_20090712_15000...  7/12/2009 15:09:54
#
#   Station                                  Show  \
# 0     CNN                          CNN Newsroom
# 1     CNN  The Situation Room With Wolf Blitzer
# 2     CNN  The Situation Room With Wolf Blitzer
# 3     CNN  The Situation Room With Wolf Blitzer
# 4     CNN     State of the Union With John King
#
#                                             IAShowID  \
# 0                   CNN_20090709_130000_CNN_Newsroom
# 1  CNN_20090708_200000_The_Situation_Room_With_Wo...
# 2  CNN_20090709_200000_The_Situation_Room_With_Wo...
# ...

# %%
# There is no data in the file 2009-10 for CNN

old_file = '/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/CNN.200907.csv'
old_date = '200907'
for x in range(1, len(lst)):
    date = d.iloc[x,0]
    if date == '200910':
        continue
    new_file = old_file.replace(old_date, date)
    df = pd.read_csv(new_file)
    df_cnn = pd.concat([df_cnn, df], axis=0)

# %%
df_cnn.tail()
# Out:
#                                                    URL       MatchDateTime  \
# 255  https://archive.org/details/CNNW_20200120_1000...  1/20/2020 10:44:11
# 256  https://archive.org/details/CNNW_20200121_0100...   1/21/2020 2:00:08
# 257  https://archive.org/details/CNNW_20200121_0000...   1/21/2020 0:11:29
# 258  https://archive.org/details/CNNW_20200102_1300...   1/2/2020 13:36:15
# 259  https://archive.org/details/CNNW_20200101_1600...   1/1/2020 16:44:14
#
#     Station                                               Show  \
# 255     CNN  Early Start With Christine Romans and Laura Ja...
# 256     CNN                                Anderson Cooper 360
# 257     CNN                              Erin Burnett OutFront
# 258     CNN       New Day With Alisyn Camerota and John Berman
# 259     CNN                     At This Hour With Kate Bolduan
#
#                                               IAShowID  \
# 255  CNNW_20200120_100000_Early_Start_With_Christin...
# ...

# %%
df_msnbc = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/MSNBC.200907.csv')

# %%
old_file = '/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/TelevisionNews_about_climate_gdeltproject/MSNBC.200907.csv'
old_date = '200907'
for x in range(1, len(lst)):
    date = d.iloc[x,0]
    new_file = old_file.replace(old_date, date)
    df = pd.read_csv(new_file)
    df_msnbc = pd.concat([df_msnbc, df], axis=0)

# %%
df_msnbc.tail()
# Out:
#                                                    URL      MatchDateTime  \
# 197  https://archive.org/details/MSNBCW_20200107_10...  1/7/2020 10:27:25
# 198  https://archive.org/details/MSNBCW_20200110_01...  1/10/2020 1:57:54
# 199  https://archive.org/details/MSNBCW_20200115_05...  1/15/2020 5:53:44
# 200  https://archive.org/details/MSNBCW_20200105_03...   1/5/2020 3:55:58
# 201  https://archive.org/details/MSNBCW_20200114_05...  1/14/2020 5:43:03
#
#     Station                                  Show  \
# 197   MSNBC                            First Look
# 198   MSNBC               All In With Chris Hayes
# 199   MSNBC     The 11th Hour With Brian Williams
# 200   MSNBC  The Last Word With Lawrence ODonnell
# 201   MSNBC                The Rachel Maddow Show
#
#                                               IAShowID  \
# 197                  MSNBCW_20200107_100000_First_Look
# 198     MSNBCW_20200110_010000_All_In_With_Chris_Hayes
# ...

# %%
df_msnbc.head()
# Out:
#                                                  URL       MatchDateTime  \
# 0  https://archive.org/details/MSNBC_20090716_030...   7/16/2009 3:42:10
# 1  https://archive.org/details/MSNBC_20090716_010...   7/16/2009 1:42:28
# 2  https://archive.org/details/MSNBC_20090727_170...  7/27/2009 17:02:05
# 3  https://archive.org/details/MSNBC_20090715_200...  7/15/2009 20:40:20
# 4  https://archive.org/details/MSNBC_20090716_010...   7/16/2009 1:41:11
#
#   Station                     Show  \
# 0   MSNBC   The Rachel Maddow Show
# 1   MSNBC   The Rachel Maddow Show
# 2   MSNBC  Andrea Mitchell Reports
# 3   MSNBC          MSNBC News Live
# 4   MSNBC   The Rachel Maddow Show
#
#                                         IAShowID  \
# 0   MSNBC_20090716_030000_The_Rachel_Maddow_Show
# 1   MSNBC_20090716_010000_The_Rachel_Maddow_Show
# 2  MSNBC_20090727_170000_Andrea_Mitchell_Reports
# 3          MSNBC_20090715_200000_MSNBC_News_Live
# 4   MSNBC_20090716_010000_The_Rachel_Maddow_Show
#
# ...

# %%
df = pd.concat([df_msnbc, df_cnn, df_fox])

# %%
df.head()
# Out:
#                                                  URL       MatchDateTime  \
# 0  https://archive.org/details/MSNBC_20090716_030...   7/16/2009 3:42:10
# 1  https://archive.org/details/MSNBC_20090716_010...   7/16/2009 1:42:28
# 2  https://archive.org/details/MSNBC_20090727_170...  7/27/2009 17:02:05
# 3  https://archive.org/details/MSNBC_20090715_200...  7/15/2009 20:40:20
# 4  https://archive.org/details/MSNBC_20090716_010...   7/16/2009 1:41:11
#
#   Station                     Show  \
# 0   MSNBC   The Rachel Maddow Show
# 1   MSNBC   The Rachel Maddow Show
# 2   MSNBC  Andrea Mitchell Reports
# 3   MSNBC          MSNBC News Live
# 4   MSNBC   The Rachel Maddow Show
#
#                                         IAShowID  \
# 0   MSNBC_20090716_030000_The_Rachel_Maddow_Show
# 1   MSNBC_20090716_010000_The_Rachel_Maddow_Show
# 2  MSNBC_20090727_170000_Andrea_Mitchell_Reports
# 3          MSNBC_20090715_200000_MSNBC_News_Live
# 4   MSNBC_20090716_010000_The_Rachel_Maddow_Show
#
# ...

# %%
df.tail()
# Out:
#                                                    URL       MatchDateTime  \
# 149  https://archive.org/details/FOXNEWSW_20200116_...  1/16/2020 11:00:05
# 150  https://archive.org/details/FOXNEWSW_20200107_...   1/7/2020 21:43:29
# 151  https://archive.org/details/FOXNEWSW_20200109_...    1/9/2020 7:35:54
# 152  https://archive.org/details/FOXNEWSW_20200121_...   1/21/2020 8:33:40
# 153  https://archive.org/details/FOXNEWSW_20200121_...   1/21/2020 8:36:48
#
#      Station                                  Show  \
# 149  FOXNEWS                       FOX and Friends
# 150  FOXNEWS           Your World With Neil Cavuto
# 151  FOXNEWS                    The Ingraham Angle
# 152  FOXNEWS  Fox News at Night With Shannon Bream
# 153  FOXNEWS  Fox News at Night With Shannon Bream
#
#                                               IAShowID  \
# 149           FOXNEWSW_20200116_110000_FOX_and_Friends
# 150  FOXNEWSW_20200107_210000_Your_World_With_Neil_...
# ...

# %%
df['date'] = pd.to_datetime(df['MatchDateTime'])

# %%
df = df.sort_values(by=['date'])
df.head()
# Out:
#                                                    URL      MatchDateTime  \
# 69   https://archive.org/details/MSNBC_20090702_180...  7/2/2009 18:40:30
# 6    https://archive.org/details/MSNBC_20090702_190...  7/2/2009 19:51:52
# 213  https://archive.org/details/FOXNEWS_20090702_2...  7/2/2009 22:54:51
# 109  https://archive.org/details/FOXNEWS_20090703_0...   7/3/2009 0:08:33
# 150  https://archive.org/details/FOXNEWS_20090703_0...   7/3/2009 2:44:09
#
#      Station                            Show  \
# 69     MSNBC                 MSNBC News Live
# 6      MSNBC                 MSNBC News Live
# 213  FOXNEWS  Special Report With Bret Baier
# 109  FOXNEWS              The OReilly Factor
# 150  FOXNEWS              Greta Van Susteren
#
#                                               IAShowID  \
# 69               MSNBC_20090702_180000_MSNBC_News_Live
# 6                MSNBC_20090702_190000_MSNBC_News_Live
# 213  FOXNEWS_20090702_221612_Special_Report_With_Br...
# ...

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#                                                  URL      MatchDateTime  \
# 0  https://archive.org/details/MSNBC_20090702_180...  7/2/2009 18:40:30
# 1  https://archive.org/details/MSNBC_20090702_190...  7/2/2009 19:51:52
# 2  https://archive.org/details/FOXNEWS_20090702_2...  7/2/2009 22:54:51
# 3  https://archive.org/details/FOXNEWS_20090703_0...   7/3/2009 0:08:33
# 4  https://archive.org/details/FOXNEWS_20090703_0...   7/3/2009 2:44:09
#
#    Station                            Show  \
# 0    MSNBC                 MSNBC News Live
# 1    MSNBC                 MSNBC News Live
# 2  FOXNEWS  Special Report With Bret Baier
# 3  FOXNEWS              The OReilly Factor
# 4  FOXNEWS              Greta Van Susteren
#
#                                             IAShowID  \
# 0              MSNBC_20090702_180000_MSNBC_News_Live
# 1              MSNBC_20090702_190000_MSNBC_News_Live
# 2  FOXNEWS_20090702_221612_Special_Report_With_Br...
# ...

# %%
df.tail()
# Out:
#                                                      URL       MatchDateTime  \
# 71593  https://archive.org/details/CNNW_20200121_1200...  1/21/2020 12:13:11
# 71594  https://archive.org/details/FOXNEWSW_20200121_...  1/21/2020 14:06:02
# 71595  https://archive.org/details/FOXNEWSW_20200121_...  1/21/2020 15:55:57
# 71596  https://archive.org/details/CNNW_20200121_1500...  1/21/2020 16:35:00
# 71597  https://archive.org/details/CNNW_20200121_1500...  1/21/2020 16:35:15
#
#        Station                                          Show  \
# 71593      CNN  New Day With Alisyn Camerota and John Berman
# 71594  FOXNEWS                             Americas Newsroom
# 71595  FOXNEWS                             Americas Newsroom
# 71596      CNN           The Senate Trial of Donald J. Trump
# 71597      CNN           The Senate Trial of Donald J. Trump
#
#                                                 IAShowID  \
# 71593  CNNW_20200121_120000_New_Day_With_Alisyn_Camer...
# ...

# %%
df.shape
# Out:
# (71598, 8)

# %%
df.drop(['MatchDateTime'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['URL', 'Station', 'Show', 'IAShowID', 'IAPreviewThumb', 'Snippet',
#        'date'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# URL               https://archive.org/details/MSNBC_20090702_180...
# Station                                                       MSNBC
# Show                                                MSNBC News Live
# IAShowID                      MSNBC_20090702_180000_MSNBC_News_Live
# IAPreviewThumb    https://archive.org/download/MSNBC_20090702_18...
# Snippet           represesentitis passed ann traordinary piece o...
# date                                            2009-07-02 18:40:30
# Name: 0, dtype: object

# %%
df.iloc[0, 5]
# Out:
# 'represesentitis passed ann traordinary piece off gigislion that would make renewawablenener the profitable kind of energy in america. it willedede our dependance on foreign oil. it will prevent the rst nsnseqnces of climate change and above all, itit h hds the promise of millions of new job,'

# %%
df.to_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/interim/gdeltproject_data_without_BBC.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71598 entries, 0 to 71597
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   URL             71598 non-null  object
#  1   Station         71598 non-null  object
#  2   Show            71577 non-null  object
#  3   IAShowID        71598 non-null  object
#  4   IAPreviewThumb  71598 non-null  object
#  5   Snippet         71598 non-null  object
#  6   date            71598 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(6)
# memory usage: 3.8+ MB

# %%
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#                                                  URL  Station  \
# 0  https://archive.org/details/MSNBC_20090702_180...    MSNBC
# 1  https://archive.org/details/MSNBC_20090702_190...    MSNBC
# 2  https://archive.org/details/FOXNEWS_20090702_2...  FOXNEWS
# 3  https://archive.org/details/FOXNEWS_20090703_0...  FOXNEWS
# 4  https://archive.org/details/FOXNEWS_20090703_0...  FOXNEWS
#
#                              Show  \
# 0                 MSNBC News Live
# 1                 MSNBC News Live
# 2  Special Report With Bret Baier
# 3              The OReilly Factor
# 4              Greta Van Susteren
#
#                                             IAShowID  \
# 0              MSNBC_20090702_180000_MSNBC_News_Live
# 1              MSNBC_20090702_190000_MSNBC_News_Live
# 2  FOXNEWS_20090702_221612_Special_Report_With_Br...
# 3         FOXNEWS_20090703_000000_The_OReilly_Factor
# 4         FOXNEWS_20090703_020000_Greta_Van_Susteren
#
# ...

# %%
df['date'].nunique()
# Out:
# 3602

# %%
df_2015 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2015.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
df_2016 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2016.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
df_2017 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2017.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
df_2018 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2018.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
 df_2019 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2019.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
df_2020 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/raw/A_New_Contextual_Dataset_For_Exploring_Climate_Change Narratives/WebNewsEnglishSnippets.2020.csv', names=['date', 'title', 'social_media_image', 'url', 'more_text'])

# %%
df = pd.concat([df_2015, df_2016, df_2017, df_2018, df_2019, df_2020])

# %%
df.shape
# Out:
# (6174022, 5)

# %%
df.head()
# Out:
#              date                                              title  \
# 0  20151104210000  NASA to deliver big news on Mars' atmosphere T...
# 1  20150929221500  Sierra Leone News: As world leaders commit to ...
# 2  20150715170000  Global slowdown boosts Africa's hopes of achie...
# 3  20151117113000  Climate Countdown: When Is a Warming Treaty No...
# 4  20151217173000  King Abdullah II Inaugurates the First and Lar...
#
#                                   social_media_image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://www.sci-tech-today.com/images/super/lar...
# 4                            http://fns1.de/g/fb.png
#
#                                                  url  \
# 0  http://www.ktvq.com/story/30436119/nasa-to-del...
# 1  http://awoko.org/2015/09/29/sierra-leone-news-...
# 2  http://www.reuters.com/article/2015/07/15/deve...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6174022 entries, 0 to 108459
# Data columns (total 5 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                int64
#  1   title               object
#  2   social_media_image  object
#  3   url                 object
#  4   more_text           object
# dtypes: int64(1), object(4)
# memory usage: 282.6+ MB

# %%
df = df.rename({'more_text':'text'}, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6174022 entries, 0 to 108459
# Data columns (total 5 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                int64
#  1   title               object
#  2   social_media_image  object
#  3   url                 object
#  4   text                object
# dtypes: int64(1), object(4)
# memory usage: 282.6+ MB

# %%
df.describe()
# Out:
#                date
# count  6.174022e+06
# mean   2.017075e+13
# std    1.508749e+10
# min    2.015010e+13
# 25%    2.016031e+13
# 50%    2.017043e+13
# 75%    2.018121e+13
# max    2.020013e+13

# %%
df['date'] = df['date'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6174022 entries, 0 to 108459
# Data columns (total 5 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                object
#  1   title               object
#  2   social_media_image  object
#  3   url                 object
#  4   text                object
# dtypes: object(5)
# memory usage: 282.6+ MB

# %%
df['date'] = df['date'].str.slice(start=0, stop=8)

# %%
df.head()
# Out:
#        date                                              title  \
# 0  20151104  NASA to deliver big news on Mars' atmosphere T...
# 1  20150929  Sierra Leone News: As world leaders commit to ...
# 2  20150715  Global slowdown boosts Africa's hopes of achie...
# 3  20151117  Climate Countdown: When Is a Warming Treaty No...
# 4  20151217  King Abdullah II Inaugurates the First and Lar...
#
#                                   social_media_image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://www.sci-tech-today.com/images/super/lar...
# 4                            http://fns1.de/g/fb.png
#
#                                                  url  \
# 0  http://www.ktvq.com/story/30436119/nasa-to-del...
# 1  http://awoko.org/2015/09/29/sierra-leone-news-...
# 2  http://www.reuters.com/article/2015/07/15/deve...
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6174022 entries, 0 to 108459
# Data columns (total 5 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   date                datetime64[ns]
#  1   title               object
#  2   social_media_image  object
#  3   url                 object
#  4   text                object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 282.6+ MB

# %%
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#          date                                              title  \
# 0  2015-11-04  NASA to deliver big news on Mars' atmosphere T...
# 1  2015-09-29  Sierra Leone News: As world leaders commit to ...
# 2  2015-07-15  Global slowdown boosts Africa's hopes of achie...
# 3  2015-11-17  Climate Countdown: When Is a Warming Treaty No...
# 4  2015-12-17  King Abdullah II Inaugurates the First and Lar...
#
#                                   social_media_image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://www.sci-tech-today.com/images/super/lar...
# 4                            http://fns1.de/g/fb.png
#
#                                                  url  \
# 0  http://www.ktvq.com/story/30436119/nasa-to-del...
# 1  http://awoko.org/2015/09/29/sierra-leone-news-...
# 2  http://www.reuters.com/article/2015/07/15/deve...
# ...

# %%
df.iloc[4,1]
# Out:
# 'King Abdullah II Inaugurates the First and Largest Utility Scale Wind Power Plant in the Kingdom and the Middle East'

# %%
df.iloc[4,4]
# Out:
# '. Renewable energy contributes to achieving sustainable economic and social development, while also playing a pivotal role in reducing the impacts of climate change. Al Tafila Wind Farm will serve as the foundation from which we will explore future energy partnerships in Jordan." Chairman of EP Global Energy'

# %%
df.to_csv('/Users/butler/Documents/GitHub/projects/Capstone_three/data/interim/gdelt_all_eng_online.csv')
