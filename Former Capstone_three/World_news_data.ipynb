# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("/Users/butler/Downloads/WorldNewsData.csv")

# %%
df.head()
# Out:
#            Date                                               Top1  \
# 0  May 01, 2018  North Korea to open its sky, South Korean medi...
# 1  May 02, 2018  'What have they got to fear? ' Trump threatens...
# 2  May 03, 2018  Hollywood isn’t simply churning out crummy rem...
# 3  May 04, 2018  Donald Trump says London hospital is 'like a w...
# 4  May 05, 2018  Missing teen’s mom implores Canada to take not...
#
#                                                 Top2  \
# 0        The Mueller probe ain't ending anytime soon
# 1  Best Garage Heater Reviews incuding electric, ...
# 2  Iran's foreign minister: US has ‘consistently ...
# 3  German seat on UN Security Council likely as I...
# 4  William and Kate release new pictures of Princ...
#
#                                                 Top3  \
# 0  BRAND NEW: 2018 – Renault Alpine A110 – Start-...
# 1  Apple just fueled everyone's biggest fear abou...
# 2  Rihanna covers the June 2018 problem of Vogue ...
# ...

# %%
df.tail()
# Out:
#               Date                                               Top1  \
# 1854  Apr 26, 2023  Uyghur death in Thai refugee detention center ...
# 1855  Apr 27, 2023  Woman whose accusation led to the lynching of ...
# 1856  Apr 28, 2023  An Ominous Heating Event Is Unfolding in the O...
# 1857  Apr 29, 2023  Russian Occupied Ukrainian City Under 'Intense...
# 1858  Apr 30, 2023  Israel will raze Khan al-Ahmar, no timetable f...
#
#                                                    Top2  \
# 1854  Avoid gatherings, wear masks: Govt advisory am...
# 1855  Russia has emptied out a Crimea base of weapon...
# 1856  Germany: Federal prosecutor takes over probe i...
# 1857  Lawsuit to proceed against ICE contractor that...
# 1858  China’s Ding Liren becomes world chess champio...
#
#                                                    Top3  \
# 1854  Biden, Yoon agree on "new level" of U.S. nucle...
# 1855           Woman at center of Till killing has died
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1859 non-null   object
#  1   Top1    1803 non-null   object
#  2   Top2    1803 non-null   object
#  3   Top3    1803 non-null   object
#  4   Top4    1803 non-null   object
#  5   Top5    1803 non-null   object
#  6   Top6    1803 non-null   object
#  7   Top7    1803 non-null   object
#  8   Top8    1803 non-null   object
#  9   Top9    1803 non-null   object
#  10  Top10   1803 non-null   object
#  11  Top11   1803 non-null   object
#  12  Top12   1803 non-null   object
#  13  Top13   1803 non-null   object
#  14  Top14   1803 non-null   object
#  15  Top15   1803 non-null   object
#  16  Top16   1803 non-null   object
#  17  Top17   1803 non-null   object
#  18  Top18   1803 non-null   object
#  19  Top19   1803 non-null   object
#  20  Top20   1803 non-null   object
# ...

# %%
df["Top1"].isnull().value_counts()
# Out:
# False    1803
# True       56
# Name: Top1, dtype: int64

# %%
np.where(df['Top2'].isnull())[0]
# Out:
# array([  10,   27,   55,   67,  102,  106,  154,  171,  172,  183,  216,
#         245,  246,  328,  346,  353,  385,  422,  529,  541,  566,  575,
#         576,  698,  716,  718,  770,  777,  850,  856,  869,  946,  954,
#         970, 1008, 1014, 1043, 1229, 1243, 1270, 1359, 1376, 1413, 1443,
#        1514, 1543, 1569, 1602, 1610, 1628, 1660, 1697, 1729, 1773, 1782,
#        1798])

# %%
idx = np.where(df['Top1'].isnull())[0].tolist()

# %%
to_remove = df.filter(idx, axis=0)

# %%
to_remove["Top2"]
# Out:
# 10      NaN
# 27      NaN
# 55      NaN
# 67      NaN
# 102     NaN
# 106     NaN
# 154     NaN
# 171     NaN
# 172     NaN
# 183     NaN
# 216     NaN
# 245     NaN
# 246     NaN
# 328     NaN
# 346     NaN
# 353     NaN
# 385     NaN
# 422     NaN
# 529     NaN
# 541     NaN
# 566     NaN
# 575     NaN
# 576     NaN
# 698     NaN
# 716     NaN
# 718     NaN
# 770     NaN
# 777     NaN
# 850     NaN
# 856     NaN
# 869     NaN
# 946     NaN
# 954     NaN
# 970     NaN
# 1008    NaN
# 1014    NaN
# 1043    NaN
# 1229    NaN
# 1243    NaN
# 1270    NaN
# 1359    NaN
# 1376    NaN
# 1413    NaN
# 1443    NaN
# 1514    NaN
# 1543    NaN
# 1569    NaN
# 1602    NaN
# 1610    NaN
# 1628    NaN
# 1660    NaN
# 1697    NaN
# 1729    NaN
# 1773    NaN
# 1782    NaN
# 1798    NaN
# Name: Top2, dtype: object

# %%
df.drop(idx, axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.drop(idx, axis=0, inplace=True)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df.isnull().value_counts()
# Out:
# Date   Top1   Top2   Top3   Top4   Top5   Top6   Top7   Top8   Top9   Top10  Top11  Top12  Top13  Top14  Top15  Top16  Top17  Top18  Top19  Top20  Top21  Top22  Top23  Top24  Top25
# False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False  False    1802
#                                                                                                                                                           True   False  False  False       1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1803 entries, 0 to 1858
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1803 non-null   object
#  1   Top1    1803 non-null   object
#  2   Top2    1803 non-null   object
#  3   Top3    1803 non-null   object
#  4   Top4    1803 non-null   object
#  5   Top5    1803 non-null   object
#  6   Top6    1803 non-null   object
#  7   Top7    1803 non-null   object
#  8   Top8    1803 non-null   object
#  9   Top9    1803 non-null   object
#  10  Top10   1803 non-null   object
#  11  Top11   1803 non-null   object
#  12  Top12   1803 non-null   object
#  13  Top13   1803 non-null   object
#  14  Top14   1803 non-null   object
#  15  Top15   1803 non-null   object
#  16  Top16   1803 non-null   object
#  17  Top17   1803 non-null   object
#  18  Top18   1803 non-null   object
#  19  Top19   1803 non-null   object
#  20  Top20   1803 non-null   object
# ...

# %%
df.iloc[0,25]
# Out:
# 'For first time health ministry will regulate descriptions on medical institutions’ websites as “advertisements” to protect patients from unscrupulous operators..prohibit misleading claims “100 percent safe surgery”..ban patients’ testimonies &amp; touting medical treatments that use unapproved drugs.'

# %%
df.iloc[0,1]
# Out:
# 'North Korea to open its sky, South Korean media reports.'

# %%
idx = []
cc = []
for i in range(1803):
    for j in range(1, 26):
       
        if i == 1245 and j == 22:
            a=3
        else:
            if "climate change" in df.iloc[i,j].lower():
                cc.append(j)
                idx.append(i)

# %%
df.iloc[1245, 22]
# Out:
# nan

# %%
len(idx)
# Out:
# 211

# %%
for i in idx:
    print(df.iloc[i,0])
# Out:
# May 30, 2018
# Jun 07, 2018
# Jul 02, 2018
# Jul 23, 2018
# Jul 29, 2018
# Jul 30, 2018
# Aug 03, 2018
# Aug 06, 2018
# Oct 08, 2018
# Oct 16, 2018
# Oct 16, 2018
# Oct 16, 2018
# Oct 16, 2018
# Oct 16, 2018
# Oct 16, 2018
# Oct 20, 2018
# Nov 02, 2018
# Nov 23, 2018
# Nov 23, 2018
# Nov 23, 2018
# Nov 24, 2018
# Nov 26, 2018
# Nov 28, 2018
# Dec 03, 2018
# Jan 08, 2019
# Jan 22, 2019
# Jan 23, 2019
# Jan 29, 2019
# Jan 31, 2019
# Feb 05, 2019
# Feb 05, 2019
# Feb 11, 2019
# Feb 19, 2019
# Feb 20, 2019
# Feb 23, 2019
# Feb 23, 2019
# Feb 26, 2019
# Feb 26, 2019
# Feb 27, 2019
# Mar 02, 2019
# Mar 10, 2019
# Mar 13, 2019
# Mar 14, 2019
# Mar 29, 2019
# Mar 30, 2019
# Apr 03, 2019
# Apr 16, 2019
# Apr 23, 2019
# Apr 27, 2019
# May 07, 2019
# May 08, 2019
# May 11, 2019
# May 13, 2019
# May 13, 2019
# Jun 04, 2019
# Jun 05, 2019
# Jun 08, 2019
# Jun 23, 2019
# Jun 30, 2019
# Jul 05, 2019
# Jul 11, 2019
# Jul 20, 2019
# Jul 28, 2019
# Jul 28, 2019
# Jul 28, 2019
# Jul 30, 2019
# ...

# %%
if 'climate change' in df.iloc[1245, 23].lower():
    print('y')

# %%
df.iloc[10,2]
# Out:
# nan

# %%
df.iloc[10,3]
# Out:
# nan
