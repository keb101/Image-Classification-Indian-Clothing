# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d1950_c20210803.csv")

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           195004         28        1445         195004       28      1445
# 1           195004         29        1530         195004       29      1530
# 2           195007          5        1800         195007        5      1800
# 3           195007          5        1830         195007        5      1830
# 4           195007         24        1440         195007       24      1440
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN  10096222      OKLAHOMA          40  ...          0         NaN
# 1         NaN  10120412         TEXAS          48  ...          0         NaN
# 2         NaN  10104927  PENNSYLVANIA          42  ...          0         NaN
# 3         NaN  10104928  PENNSYLVANIA          42  ...          0         NaN
# 4         NaN  10104929  PENNSYLVANIA          42  ...          0         NaN
#
# ...

# %%
df.shape
# Out:
# (223, 51)

# %%
old_file = "/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d1950_c20210803.csv"
old_date = '1950'
for i in range(1951, 1972):
    new_date = str(i)
    new_file = old_file.replace(old_date, new_date)
    df_new = pd.read_csv(new_file)
    df = pd.concat([df, df_new])

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           195004         28        1445         195004       28      1445
# 1           195004         29        1530         195004       29      1530
# 2           195007          5        1800         195007        5      1800
# 3           195007          5        1830         195007        5      1830
# 4           195007         24        1440         195007       24      1440
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN  10096222      OKLAHOMA          40  ...          0         NaN
# 1         NaN  10120412         TEXAS          48  ...          0         NaN
# 2         NaN  10104927  PENNSYLVANIA          42  ...          0         NaN
# 3         NaN  10104928  PENNSYLVANIA          42  ...          0         NaN
# 4         NaN  10104929  PENNSYLVANIA          42  ...          0         NaN
#
# ...

# %%
df.tail()
# Out:
#       BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 3466           197108         27        1545         197108       27
# 3467           197108         27        1700         197108       27
# 3468           197108         29        1145         197108       29
# 3469           197108         29        1650         197108       29
# 3470           197109          1        1415         197109        1
#
#       END_TIME  EPISODE_ID  EVENT_ID    STATE  STATE_FIPS  ...  END_RANGE  \
# 3466      1545         NaN  10000486  FLORIDA          12  ...          0
# 3467      1700         NaN  10000487  FLORIDA          12  ...          0
# 3468      1145         NaN  10000488  FLORIDA          12  ...          0
# 3469      1650         NaN  10000489  FLORIDA          12  ...          0
# 3470      1415         NaN  10000490  FLORIDA          12  ...          0
#
#      END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT  END_LON  \
# ...

# %%
df.shape
# Out:
# (42922, 51)

# %%
old_file = "/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d1972_c20220425.csv"
old_date = '1972'
for i in range(1972, 2011):
    new_date = str(i)
    
    new_file = old_file.replace(old_date, new_date)
    
    df_new = pd.read_csv(new_file)
   
    df = pd.concat([df, df_new])
# Out:
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_20166/67922992.py:8: DtypeWarning: Columns (26,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(new_file)
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_20166/67922992.py:8: DtypeWarning: Columns (26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(new_file)
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_20166/67922992.py:8: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(new_file)
# /var/folders/nv/lggm200n09vgfy5n8_6lcz6c0000gn/T/ipykernel_20166/67922992.py:8: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_new = pd.read_csv(new_file)
# ...

# %%
df[df['BEGIN_YEARMONTH'] == 199006]
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 7               199006         12        2055         199006       12
# 8               199006         12        2110         199006       12
# 9               199006          8        1602         199006        8
# 10              199006          8        1617         199006        8
# 11              199006          2        1150         199006        2
# ...                ...        ...         ...            ...      ...
# 10871           199006          1        2045         199006        1
# 10872           199006         11        2130         199006       11
# 10873           199006         28         530         199006       28
# 10879           199006          6        1845         199006        6
# 10899           199006          4        2333         199006        4
#
#        END_TIME  EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  \
# ...

# %%
df.shape
# Out:
# (1122787, 51)

# %%
df.shape
# Out:
# (1122787, 51)

# %%
df11 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2011_c20230417.csv")
df12 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2012_c20221216.csv")
df13 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2013_c20230118.csv")
df14 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2014_c20230330.csv")
df15 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2015_c20220425.csv")
df16 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2016_c20220719.csv")
df17 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2017_c20230317.csv")
df18 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2019_c20230118.csv")
df19 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2020_c20230417.csv")
df20 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2021_c20230516.csv")
df21 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2022_c20230616.csv")
df22 = pd.read_csv("/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d2018_c20230616.csv")

# %%
df = pd.concat([df, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23])

# %%
df.shape
# Out:
# (1942077, 51)

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           195004         28        1445         195004       28      1445
# 1           195004         29        1530         195004       29      1530
# 2           195007          5        1800         195007        5      1800
# 3           195007          5        1830         195007        5      1830
# 4           195007         24        1440         195007       24      1440
#
#    EPISODE_ID  EVENT_ID         STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN  10096222      OKLAHOMA        40.0  ...        0.0         NaN
# 1         NaN  10120412         TEXAS        48.0  ...        0.0         NaN
# 2         NaN  10104927  PENNSYLVANIA        42.0  ...        0.0         NaN
# 3         NaN  10104928  PENNSYLVANIA        42.0  ...        0.0         NaN
# 4         NaN  10104929  PENNSYLVANIA        42.0  ...        0.0         NaN
#
# ...

# %%
df['year'] = df['BEGIN_YEARMONTH'].astype(str)
df['year'] = df['year'].str[0:4]

# %%
df['month'] = df['BEGIN_YEARMONTH'].astype(str)
df['month'] = df['month'].str[-2:]

# %%
df['day'] = df['BEGIN_DAY'].astype(str)

# %%
df['begin_date'] = pd.to_datetime(df[['year', 'month', 'day']])

# %%
df['year'] = df['END_YEARMONTH'].astype(str)
df['year'] = df['year'].str[0:4]

# %%
df['month'] = df['END_YEARMONTH'].astype(str)
df['month'] = df['month'].str[-2:]

# %%
df['day'] = df['END_DAY'].astype(str)

# %%
df['end_date'] = pd.to_datetime(df[['year', 'month', 'day']])

# %%
df['begin_date'] = pd.to_datetime(df['end_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

# %%
df.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE', 'year', 'month',
#        'day', 'begin_date', 'end_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1942077 entries, 0 to 62696
# Data columns (total 56 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   BEGIN_YEARMONTH     int64
#  1   BEGIN_DAY           int64
#  2   BEGIN_TIME          int64
#  3   END_YEARMONTH       int64
#  4   END_DAY             int64
#  5   END_TIME            int64
#  6   EPISODE_ID          float64
#  7   EVENT_ID            int64
#  8   STATE               object
#  9   STATE_FIPS          float64
#  10  YEAR                int64
#  11  MONTH_NAME          object
#  12  EVENT_TYPE          object
#  13  CZ_TYPE             object
#  14  CZ_FIPS             int64
#  15  CZ_NAME             object
#  16  WFO                 object
#  17  BEGIN_DATE_TIME     object
#  18  CZ_TIMEZONE         object
#  19  END_DATE_TIME       object
#  20  INJURIES_DIRECT     int64
#  21  INJURIES_INDIRECT   int64
#  22  DEATHS_DIRECT       int64
#  23  DEATHS_INDIRECT     int64
# ...

# %%
df.drop(['BEGIN_DAY', 'END_YEARMONTH', 'END_DAY', 'month', 'day'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_TIME', 'END_TIME', 'EPISODE_ID', 'EVENT_ID',
#        'STATE', 'STATE_FIPS', 'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE',
#        'CZ_FIPS', 'CZ_NAME', 'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE',
#        'END_DATE_TIME', 'INJURIES_DIRECT', 'INJURIES_INDIRECT',
#        'DEATHS_DIRECT', 'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS',
#        'SOURCE', 'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY',
#        'TOR_F_SCALE', 'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO',
#        'TOR_OTHER_CZ_STATE', 'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME',
#        'BEGIN_RANGE', 'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE',
#        'END_AZIMUTH', 'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT',
#        'END_LON', 'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE',
#        'year', 'begin_date', 'end_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1942077 entries, 0 to 62696
# Data columns (total 51 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   BEGIN_YEARMONTH     int64
#  1   BEGIN_TIME          int64
#  2   END_TIME            int64
#  3   EPISODE_ID          float64
#  4   EVENT_ID            int64
#  5   STATE               object
#  6   STATE_FIPS          float64
#  7   YEAR                int64
#  8   MONTH_NAME          object
#  9   EVENT_TYPE          object
#  10  CZ_TYPE             object
#  11  CZ_FIPS             int64
#  12  CZ_NAME             object
#  13  WFO                 object
#  14  BEGIN_DATE_TIME     object
#  15  CZ_TIMEZONE         object
#  16  END_DATE_TIME       object
#  17  INJURIES_DIRECT     int64
#  18  INJURIES_INDIRECT   int64
#  19  DEATHS_DIRECT       int64
#  20  DEATHS_INDIRECT     int64
#  21  DAMAGE_PROPERTY     object
#  22  DAMAGE_CROPS        object
#  23  SOURCE              object
# ...

# %%
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_TIME  END_TIME  EPISODE_ID  EVENT_ID         STATE  \
# 0           195004        1445      1445         NaN  10096222      OKLAHOMA
# 1           195004        1530      1530         NaN  10120412         TEXAS
# 2           195007        1800      1800         NaN  10104927  PENNSYLVANIA
# 3           195007        1830      1830         NaN  10104928  PENNSYLVANIA
# 4           195007        1440      1440         NaN  10104929  PENNSYLVANIA
#
#    STATE_FIPS  YEAR MONTH_NAME EVENT_TYPE  ... BEGIN_LAT  BEGIN_LON END_LAT  \
# 0        40.0  1950      April    Tornado  ...     35.12     -99.20   35.17
# 1        48.0  1950      April    Tornado  ...     31.90     -98.60   31.73
# 2        42.0  1950       July    Tornado  ...     40.58     -75.70   40.65
# 3        42.0  1950       July    Tornado  ...     40.60     -76.75     NaN
# 4        42.0  1950       July    Tornado  ...     41.63     -79.68     NaN
#
# ...

# %%
df['begin_date'].nunique()
# Out:
# 20124

# %%
df.reset_index(names=['number_of_storms'], inplace=True)

# %%
df_number = df.groupby(df['BEGIN_YEARMONTH']).aggregate({'number_of_storms': 'sum'})
df_number.shape
# Out:
# (872, 1)

# %%
df_number.head()
# Out:
#                  number_of_storms
# BEGIN_YEARMONTH
# 195001                       1079
# 195002                       2392
# 195003                       2186
# 195004                       1081
# 195005                       7643

# %%
df_number.reset_index(inplace=True)

# %%
df_number.head()
# Out:
#    BEGIN_YEARMONTH  number_of_storms
# 0           195001              1079
# 1           195002              2392
# 2           195003              2186
# 3           195004              1081
# 4           195005              7643

# %%
df_number.tail()
# Out:
#      BEGIN_YEARMONTH  number_of_storms
# 867           202208         233546659
# 868           202209         138184067
# 869           202210          29191298
# 870           202211         153873761
# 871           202212         377944950

# %%
plt.plot(df_number['BEGIN_YEARMONTH'], df_number['number_of_storms'])
plt.show()

# %%
df_number['log_number'] = np.log(df_number['number_of_storms'])

# %%
df_number.head()
# Out:
#    BEGIN_YEARMONTH  number_of_storms  log_number
# 0           195001              1079    6.983790
# 1           195002              2392    7.779885
# 2           195003              2186    7.689829
# 3           195004              1081    6.985642
# 4           195005              7643    8.941545

# %%
df_number.tail()
# Out:
#      BEGIN_YEARMONTH  number_of_storms  log_number
# 867           202208         233546659   19.268892
# 868           202209         138184067   18.744097
# 869           202210          29191298   17.189381
# 870           202211         153873761   18.851643
# 871           202212         377944950   19.750259

# %%
df_number.isnull().value_counts()
# Out:
# BEGIN_YEARMONTH  number_of_storms  log_number
# False            False             False         872
# dtype: int64

# %%
df_number[df_number['BEGIN_YEARMONTH']== 199012]
# Out:
#      BEGIN_YEARMONTH  number_of_storms  log_number
# 489           199012            849442   13.652335

# %%
plt.plot(df_number['BEGIN_YEARMONTH'], df_number['log_number'])
plt.show()

# %%
df_year = df.groupby(df['year']).aggregate({'number_of_storms': 'sum'})
df_year.head()
# Out:
#       number_of_storms
# year
# 1950             24753
# 1951             36046
# 1952             36856
# 1953            120786
# 1954            185136

# %%
df_year.tail()
# Out:
#       number_of_storms
# year
# 2018        3930851112
# 2019        2302388011
# 2020        1874954466
# 2021        1884089805
# 2022        2409464071

# %%
df_year[df_year['number_of_storms'] == 1990]
# Out:
# Empty DataFrame
# Columns: [number_of_storms]
# Index: []

# %%
df2 = pd.read_csv('/Users/butler/Documents/GitHub/projects/Storm_events/StormEvents_details-ftp_v1.0_d1990_c20220425.csv')

# %%
df2.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           199007         31        2155         199007       31      2155
# 1           199005         16        1320         199005       16      1320
# 2           199012         21        1107         199012       21      1107
# 3           199004          1        1812         199004        1      1812
# 4           199003         12        2147         199003       12      2147
#
#    EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0         NaN   9984134    ARIZONA           4  ...          0         NaN
# 1         NaN  10070939   MISSOURI          29  ...          0         NaN
# 2         NaN  10046816  LOUISIANA          22  ...          0         NaN
# 3         NaN   9981938    ALABAMA           1  ...          0         NaN
# 4         NaN  10037649     KANSAS          20  ...          0         NaN
#
# ...

# %%
df_year.number_of_storms.plot()
# Out:
# <Axes: xlabel='year'>

# %%
df_year.isnull().value_counts()
# Out:
# number_of_storms
# False               73
# dtype: int64

# %%
df_year.shape
# Out:
# (73, 1)

# %%
df_year['log_number_of_storms'] = np.log(df_year['number_of_storms'])

# %%
df_year.log_number_of_storms.plot()
# Out:
# <Axes: xlabel='year'>
